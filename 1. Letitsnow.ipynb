# %% [markdown]
# LETITSNOW

# %%
print("Lé Tits Now! 🇫🇷")
# Out:
# Lé Tits Now! 🇫🇷

# %%
import pandas as pd

# %%
df = pd.read_excel("C:/Users/Henrik/Documents/LeTitsNow/letitsnowCRIME.xlsx", engine='openpyxl')

# %%
#Drop unecessary columns
df = df.drop(["Unnamed: 6", "Unnamed: 7", "Brott"], axis=1)
df
# Out:
#                  Region      År Period Antal /100 000 inv
# 0                   NaN     NaN    NaN   NaN          NaN
# 1          Gotlands län  1998.0    Dec    ..           ..
# 2          Gotlands län  2002.0    Okt    ..           ..
# 3          Gotlands län  2007.0    Nov    ..           ..
# 4          Gotlands län  2011.0    Nov    ..           ..
# ...                 ...     ...    ...   ...          ...
# 2516  Östergötlands län  2008.0    Mar    40            9
# 2517  Östergötlands län  2010.0    Jan    38            9
# 2518  Östergötlands län  2010.0    Mar    38            9
# 2519  Östergötlands län  2012.0    Dec    38            9
# 2520  Östergötlands län  2013.0    Mar    41            9
#
# [2521 rows x 5 columns]

# %%
#Drop first row (onlu NaN)
df = df.drop([0])

# %%
df
# Out:
#                  Region      År Period Antal /100 000 inv
# 1          Gotlands län  1998.0    Dec    ..           ..
# 2          Gotlands län  2002.0    Okt    ..           ..
# 3          Gotlands län  2007.0    Nov    ..           ..
# 4          Gotlands län  2011.0    Nov    ..           ..
# 5          Gotlands län  2012.0    Feb    ..           ..
# ...                 ...     ...    ...   ...          ...
# 2516  Östergötlands län  2008.0    Mar    40            9
# 2517  Östergötlands län  2010.0    Jan    38            9
# 2518  Östergötlands län  2010.0    Mar    38            9
# 2519  Östergötlands län  2012.0    Dec    38            9
# 2520  Östergötlands län  2013.0    Mar    41            9
#
# [2520 rows x 5 columns]

# %%
#Dictionary to translate months with
m = {
    "Jan": "1",
    "Feb": "2",
    "Mar": "3",
    "Apr": "4",
    "Maj": "5",
    "Jun":"6",
    "Jul":"7",
    "Aug":"8",
    "Sep":"9",
    "Okt":"10",
    "Nov":"11",
    "Dec": "12"
    }

# %%
#Translate string to int months
new_months = []
for month in df["Period"]:
    new_months.append(m[month])
df["Period"] = new_months
df["År"] = df["År"].apply(lambda x: int(x))

# %%
df
# Out:
#                  Region    År Period Antal /100 000 inv
# 1          Gotlands län  1998     12    ..           ..
# 2          Gotlands län  2002     10    ..           ..
# 3          Gotlands län  2007     11    ..           ..
# 4          Gotlands län  2011     11    ..           ..
# 5          Gotlands län  2012      2    ..           ..
# ...                 ...   ...    ...   ...          ...
# 2516  Östergötlands län  2008      3    40            9
# 2517  Östergötlands län  2010      1    38            9
# 2518  Östergötlands län  2010      3    38            9
# 2519  Östergötlands län  2012     12    38            9
# 2520  Östergötlands län  2013      3    41            9
#
# [2520 rows x 5 columns]

# %%
#Create new column "Date"
new_col = []
for a,p in zip(df["År"], df["Period"]):
    if int(p) < 10:
        new_col.append(str(a)+'-'+'0'+str(p))
    else:
        new_col.append(str(a)+'-'+str(p))
df["Date"]= new_col
df = df.drop(["År", "Period"], axis=1)
df.sort_values(by="Date")
# Out:
#                     Region Antal /100 000 inv     Date
# 981   Västra Götalands län   258           17  1995-01
# 43            Gotlands län     6           10  1995-01
# 240      Södermanlands län    28           11  1995-01
# 440             Örebro län    34           12  1995-01
# 2093        Jönköpings län    23            7  1995-01
# ...                    ...   ...          ...      ...
# 716           Dalarnas län    42           15  2014-12
# 857             Kalmar län    37           16  2014-12
# 802       Västmanlands län    40           15  2014-12
# 261            Uppsala län    39           11  2014-12
# 316      Östergötlands län    50           11  2014-12
#
# [2520 rows x 4 columns]

# %%
df.to_csv("crime_cleaned.csv")

# %%
weather = pd.read_csv("C:/Users/Henrik/Documents/LeTitsNow/weather_data_new.csv")

# %%
alla_ortnamn = weather["location"].unique()

# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
def scrape_wikipedia(alla_ortnamn):
    alla_regioner = []
    for ort in alla_ortnamn:

        try:
            new_ort = ort.split(' ')[0]

            r = requests.get(url = "https://sv.wikipedia.org/wiki/"+new_ort, timeout=5)
            soup = BeautifulSoup(r.text)
            region = soup.find(title="Län orten ligger i").find('span').find("a")["title"]
            alla_regioner.append(region)

        except:
            alla_regioner.append("Not found")
            print("Not found")
    return alla_regioner

# %%
allaR = ['Norrbottens län',
 'Not found',
 'Västerbottens län',
 'Västra Götalands län',
 'Not found',
 'Kalmar län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Västerbottens län',
 'Not found',
 'Not found',
 'Dalarnas län',
 'Not found',
 'Not found',
 'Västerbottens län',
 'Not found',
 'Not found',
 'Västra Götalands län',
 'Not found',
 'Gävleborgs län',
 'Not found',
 'Dalarnas län',
 'Skåne län',
 'Uppsala län',
 'Not found',
 'Södermanlands län',
 'Not found',
 'Västra Götalands län',
 'Gävleborgs län',
 'Jämtlands län',
 'Dalarnas län',
 'Västra Götalands län',
 'Jönköpings län',
 'Not found',
 'Västernorrlands län',
 'Skåne län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Skåne län',
 'Västerbottens län',
 'Västra Götalands län',
 'Not found',
 'Östergötlands län',
 'Värmlands län',
 'Dalarnas län',
 'Stockholms län',
 'Västra Götalands län',
 'Skåne län',
 'Örebro län',
 'Gävleborgs län',
 'Not found',
 'Not found',
 'Not found',
 'Jämtlands län',
 'Not found',
 'Not found',
 'Hallands län',
 'Kalmar län',
 'Uppsala län',
 'Blekinge län',
 'Södermanlands län',
 'Not found',
 'Not found',
 'Not found',
 'Skåne län',
 'Not found',
 'Not found',
 'Östergötlands län',
 'Not found',
 'Västernorrlands län',
 'Västra Götalands län',
 'Dalarnas län',
 'Blekinge län',
 'Not found',
 'Västmanlands län',
 'Västra Götalands län',
 'Not found',
 'Not found',
 'Västerbottens län',
 'Västra Götalands län',
 'Dalarnas län',
 'Not found',
 'Not found',
 'Norrbottens län',
 'Östergötlands län',
 'Not found',
 'Not found',
 'Västerbottens län',
 'Not found',
 'Örebro län',
 'Värmlands län',
 'Not found',
 'Västra Götalands län',
 'Västra Götalands län',
 'Not found',
 'Gävleborgs län',
 'Not found',
 'Not found',
 'Not found',
 'Hallands län',
 'Not found',
 'Jämtlands län',
 'Not found',
 'Norrbottens län',
 'Norrbottens län',
 'Not found',
 'Not found',
 'Gävleborgs län',
 'Jämtlands län',
 'Not found',
 'Not found',
 'Gotlands län',
 'Not found',
 'Västra Götalands län',
 'Västra Götalands län',
 'Not found',
 'Not found',
 'Dalarnas län',
 'Jämtlands län',
 'Not found',
 'Västra Götalands län',
 'Örebro län',
 'Not found',
 'Gävleborgs län',
 'Not found',
 'Not found',
 'Not found',
 'Västra Götalands län',
 'Not found',
 'Gävleborgs län',
 'Not found',
 'Not found',
 'Södermanlands län',
 'Not found',
 'Not found',
 'Södermanlands län',
 'Not found',
 'Not found',
 'Västernorrlands län',
 'Västra Götalands län',
 'Not found',
 'Not found',
 'Not found',
 'Värmlands län',
 'Not found',
 'Not found',
 'Not found',
 'Värmlands län',
 'Dalarnas län',
 'Not found',
 'Norrbottens län',
 'Norrbottens län',
 'Not found',
 'Gävleborgs län',
 'Jönköpings län',
 'Västerbottens län',
 'Norrbottens län',
 'Kalmar län',
 'Västerbottens län',
 'Norrbottens län',
 'Norrbottens län',
 'Blekinge län',
 'Örebro län',
 'Not found',
 'Norrbottens län',
 'Not found',
 'Not found',
 'Not found',
 'Gävleborgs län',
 'Not found',
 'Not found',
 'Not found',
 'Norrbottens län',
 'Östergötlands län',
 'Västerbottens län',
 'Skåne län',
 'Norrbottens län',
 'Not found',
 'Hallands län',
 'Norrbottens län',
 'Västmanlands län',
 'Örebro län',
 'Not found',
 'Västernorrlands län',
 'Skåne län',
 'Värmlands län',
 'Not found',
 'Not found',
 'Not found',
 'Västmanlands län',
 'Not found',
 'Not found',
 'Not found',
 'Jämtlands län',
 'Not found',
 'Hallands län',
 'Not found',
 'Norrbottens län',
 'Jönköpings län',
 'Västra Götalands län',
 'Västernorrlands län',
 'Hallands län',
 'Norrbottens län',
 'Skåne län',
 'Not found',
 'Not found',
 'Norrbottens län',
 'Västerbottens län',
 'Dalarnas län',
 'Värmlands län',
 'Kronobergs län',
 'Värmlands län',
 'Kronobergs län',
 'Västra Götalands län',
 'Not found',
 'Not found',
 'Östergötlands län',
 'Östergötlands län',
 'Gotlands län',
 'Kronobergs län',
 'Not found',
 'Jämtlands län',
 'Not found',
 'Gävleborgs län',
 'Not found',
 'Dalarnas län',
 'Not found',
 'Norrbottens län',
 'Skåne län',
 'Not found',
 'Not found',
 'Västra Götalands län',
 'Not found',
 'Not found',
 'Kalmar län',
 'Jämtlands län',
 'Skåne län',
 'Västerbottens län',
 'Not found',
 'Norrbottens län',
 'Jönköpings län',
 'Dalarnas län',
 'Västerbottens län',
 'Not found',
 'Västra Götalands län',
 'Södermanlands län',
 'Västra Götalands län',
 'Kronobergs län',
 'Norrbottens län',
 'Not found',
 'Kronobergs län',
 'Not found',
 'Not found',
 'Norrbottens län',
 'Östergötlands län',
 'Västernorrlands län',
 'Skåne län',
 'Norrbottens län',
 'Västernorrlands län',
 'Jämtlands län',
 'Not found',
 'Not found',
 'Gotlands län',
 'Dalarnas län',
 'Kalmar län',
 'Kalmar län',
 'Jämtlands län',
 'Gävleborgs län',
 'Not found',
 'Not found',
 'Västmanlands län',
 'Not found',
 'Västernorrlands län',
 'Not found',
 'Dalarnas län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Stockholms län',
 'Dalarnas län',
 'Skåne län',
 'Södermanlands län',
 'Stockholms län',
 'Stockholms län',
 'Södermanlands län',
 'Västernorrlands län',
 'Jönköpings län',
 'Gävleborgs län',
 'Gävleborgs län',
 'Not found',
 'Blekinge län',
 'Not found',
 'Hallands län',
 'Kalmar län',
 'Dalarnas län',
 'Skåne län',
 'Kalmar län',
 'Södermanlands län',
 'Norrbottens län',
 'Norrbottens län',
 'Värmlands län',
 'Norrbottens län',
 'Kronobergs län',
 'Not found',
 'Not found',
 'Not found',
 'Jönköpings län',
 'Not found',
 'Västernorrlands län',
 'Not found',
 'Västmanlands län',
 'Jämtlands län',
 'Not found',
 'Västra Götalands län',
 'Jämtlands län',
 'Västerbottens län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Norrbottens län',
 'Västmanlands län',
 'Not found',
 'Stockholms län',
 'Not found',
 'Not found',
 'Not found',
 'Gävleborgs län',
 'Skåne län',
 'Västra Götalands län',
 'Västra Götalands län',
 'Dalarnas län',
 'Not found',
 'Jönköpings län',
 'Not found',
 'Södermanlands län',
 'Västra Götalands län',
 'Not found',
 'Västernorrlands län',
 'Västerbottens län',
 'Örebro län',
 'Skåne län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Örebro län',
 'Not found',
 'Värmlands län',
 'Not found',
 'Not found',
 'Norrbottens län',
 'Norrbottens län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Östergötlands län',
 'Värmlands län',
 'Dalarnas län',
 'Västra Götalands län',
 'Jönköpings län',
 'Not found',
 'Västra Götalands län',
 'Gävleborgs län',
 'Not found',
 'Dalarnas län',
 'Östergötlands län',
 'Not found',
 'Stockholms län',
 'Not found',
 'Not found',
 'Västra Götalands län',
 'Not found',
 'Not found',
 'Not found',
 'Västerbottens län',
 'Not found',
 'Östergötlands län',
 'Not found',
 'Not found',
 'Skåne län',
 'Not found',
 'Östergötlands län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Kalmar län',
 'Not found',
 'Norrbottens län',
 'Skåne län',
 'Not found',
 'Värmlands län',
 'Västra Götalands län',
 'Västernorrlands län',
 'Västra Götalands län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Östergötlands län',
 'Södermanlands län',
 'Jämtlands län',
 'Stockholms län',
 'Jämtlands län',
 'Hallands län',
 'Uppsala län',
 'Uppsala län',
 'Hallands län',
 'Västra Götalands län',
 'Norrbottens län',
 'Norrbottens län',
 'Not found',
 'Södermanlands län',
 'Not found',
 'Gotlands län',
 'Uppsala län',
 'Skåne län',
 'Södermanlands län',
 'Norrbottens län',
 'Not found',
 'Västra Götalands län',
 'Not found',
 'Västerbottens län',
 'Not found',
 'Värmlands län',
 'Stockholms län',
 'Södermanlands län',
 'Not found',
 'Uppsala län',
 'Not found',
 'Dalarnas län',
 'Not found',
 'Västra Götalands län',
 'Skåne län',
 'Jämtlands län',
 'Jämtlands län',
 'Not found',
 'Not found',
 'Örebro län',
 'Västra Götalands län',
 'Kronobergs län',
 'Uppsala län',
 'Östergötlands län',
 'Södermanlands län',
 'Skåne län',
 'Not found',
 'Not found',
 'Not found',
 'Västra Götalands län',
 'Värmlands län',
 'Jämtlands län',
 'Västerbottens län',
 'Not found',
 'Örebro län',
 'Östergötlands län',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Not found',
 'Västernorrlands län',
 'Not found',
 'Gävleborgs län',
 'Uppsala län',
 'Not found',
 'Not found',
 'Not found',
 'Not found']

# %%
#ortbok = {}
#for ort, reg in zip(weather["location"].unique().tolist(), allaR):
    
#    ortbok[ort] = reg

# %%
ortbok = {}
for ort in weather["location"].unique().tolist():
    ortbok[ort] = "Not found"
ortbok
# Out:
# {'Abisko': 'Not found',
#  'Abraur': 'Not found',
#  'Adak': 'Not found',
#  'Alingsås D': 'Not found',
#  'Almdalen': 'Not found',
#  'Ankarsrum D': 'Not found',
#  'Ankarvattnet D': 'Not found',
#  'Arjeplog-Myrheden D': 'Not found',
#  'Asker D': 'Not found',
#  'Askim D': 'Not found',
#  'Aspa D': 'Not found',
#  'Aspeå': 'Not found',
#  'Austers D': 'Not found',
#  'Avasjö-Borgafjäll D': 'Not found',
#  'Avesta': 'Not found',
#  'Backe D': 'Not found',
#  'Bakarebo D': 'Not found',
#  'Balsjö D': 'Not found',
#  'Baramossa': 'Not found',
#  'Bastansjö D': 'Not found',
#  'Bengtsfors': 'Not found',
#  'Berg': 'Not found',
#  'Bergsjö': 'Not found',
#  'Bispgården': 'Not found',
#  'Bjursås': 'Not found',
#  'Bjärnum D': 'Not found',
#  'Björklinge D': 'Not found',
#  'Björkudden': 'Not found',
#  'Björkvik D': 'Not found',
#  'Blaiken D': 'Not found',
#  'Bollebygd': 'Not found',
#  'Bollnäs D': 'Not found',
#  'Borgvattnet D': 'Not found',
#  'Borlänge D': 'Not found',
#  'Borås': 'Not found',
#  'Bottnaryd': 'Not found',
#  'Bottnen': 'Not found',
#  'Bredbyn D': 'Not found',
#  'Bromölla': 'Not found',
#  'Brovallen': 'Not found',
#  'Brände': 'Not found',
#  'Brännberg D': 'Not found',
#  'Brännforssund': 'Not found',
#  'Brösarp D': 'Not found',
#  'Bygdsiljum D': 'Not found',
#  'Bäckefors': 'Not found',
#  'Bäverträsk': 'Not found',
#  'Börrum D': 'Not found',
#  'Charlottenberg': 'Not found',
#  'Dala-Järna D': 'Not found',
#  'Dalarö D': 'Not found',
#  'Dalstorp': 'Not found',
#  'Degeberga D': 'Not found',
#  'Degerfors D': 'Not found',
#  'Delsbo': 'Not found',
#  'Digernäset D': 'Not found',
#  'Djursätra': 'Not found',
#  'Djurö D': 'Not found',
#  'Dödre': 'Not found',
#  'Ed D': 'Not found',
#  'Edevik': 'Not found',
#  'Eftra D': 'Not found',
#  'Emmaboda D': 'Not found',
#  'Enköping': 'Not found',
#  'Eringsboda D': 'Not found',
#  'Eskilstuna': 'Not found',
#  'Esrange': 'Not found',
#  'Fagerhult D': 'Not found',
#  'Falköping-Valtorp D': 'Not found',
#  'Falsterbo': 'Not found',
#  'Falun-Lugnet': 'Not found',
#  'Finnbacka D': 'Not found',
#  'Finspång': 'Not found',
#  'Fjällsjönäs': 'Not found',
#  'Forse': 'Not found',
#  'Fotskäl D': 'Not found',
#  'Fredriksberg': 'Not found',
#  'Fridlevstad D': 'Not found',
#  'Frostviken D': 'Not found',
#  'Frändesta': 'Not found',
#  'Fägre D': 'Not found',
#  'Fågelberget D': 'Not found',
#  'Fågelsjö D': 'Not found',
#  'Gargnäs D': 'Not found',
#  'Gendalen': 'Not found',
#  'Gesunda D': 'Not found',
#  'Gillastig': 'Not found',
#  'Glindran': 'Not found',
#  'Glommersträsk': 'Not found',
#  'Godegård D': 'Not found',
#  'Granhed D': 'Not found',
#  'Granhult': 'Not found',
#  'Granö D': 'Not found',
#  'Grebbeshult': 'Not found',
#  'Grythyttan': 'Not found',
#  'Gräsås D': 'Not found',
#  'Grönliden': 'Not found',
#  'Gullspång': 'Not found',
#  'Gustavsfors': 'Not found',
#  'Gustorp D': 'Not found',
#  'Gästrike-Hammarby D': 'Not found',
#  'Gävle-Åbyggeby': 'Not found',
#  'Gåltjärn': 'Not found',
#  'Halmstad': 'Not found',
#  'Hammarö': 'Not found',
#  'Hammerdal D': 'Not found',
#  'Handsjön D': 'Not found',
#  'Haparanda D': 'Not found',
#  'Harads D': 'Not found',
#  'Hattsjöbäcken D': 'Not found',
#  'Heden': 'Not found',
#  'Hedesunda': 'Not found',
#  'Hedeviken': 'Not found',
#  'Hejnum': 'Not found',
#  'Hellerö': 'Not found',
#  'Hemse': 'Not found',
#  'Hennan D': 'Not found',
#  'Henån': 'Not found',
#  'Herrljunga D': 'Not found',
#  'Hestra D': 'Not found',
#  'Hid D': 'Not found',
#  'Hillersboda': 'Not found',
#  'Hillsand': 'Not found',
#  'Hinshult': 'Not found',
#  'Hjo': 'Not found',
#  'Hjortkvarn D': 'Not found',
#  'Hoburg D': 'Not found',
#  'Hofors': 'Not found',
#  'Holmbo D': 'Not found',
#  'Holmfors D': 'Not found',
#  'Holmön D': 'Not found',
#  'Horred': 'Not found',
#  'Hov': 'Not found',
#  'Hudiksvall': 'Not found',
#  'Hult D': 'Not found',
#  'Hyltan': 'Not found',
#  'Hyndevad': 'Not found',
#  'Häggberget D': 'Not found',
#  'Häggårda': 'Not found',
#  'Hälleforsnäs D': 'Not found',
#  'Härjeåsjön': 'Not found',
#  'Härnebo': 'Not found',
#  'Härnösand': 'Not found',
#  'Härryda': 'Not found',
#  'Härsnäs': 'Not found',
#  'Hässleby D': 'Not found',
#  'Håvelund': 'Not found',
#  'Högboda': 'Not found',
#  'Högemålen D': 'Not found',
#  'Höglekardalen': 'Not found',
#  'Högsbo': 'Not found',
#  'Höljes': 'Not found',
#  'Idre D': 'Not found',
#  'Jarhois': 'Not found',
#  'Jukkasjärvi D': 'Not found',
#  'Jäckvik': 'Not found',
#  'Järpströmmen': 'Not found',
#  'Järvsö': 'Not found',
#  'Jönköping': 'Not found',
#  'Jörn D': 'Not found',
#  'Kalix D': 'Not found',
#  'Kalmar D': 'Not found',
#  'Kalvträsk D': 'Not found',
#  'Kangos D': 'Not found',
#  'Karesuando': 'Not found',
#  'Karlshamn': 'Not found',
#  'Karlskoga': 'Not found',
#  'Karlstad-Skåre': 'Not found',
#  'Karungi': 'Not found',
#  'Katterjåkk': 'Not found',
#  'Kaxås-Åflo D': 'Not found',
#  'Kilafors D': 'Not found',
#  'Kilagården': 'Not found',
#  'Kindsboda': 'Not found',
#  'Kindsjön D': 'Not found',
#  'Kiruna': 'Not found',
#  'Kisa D': 'Not found',
#  'Kittelfjäll D': 'Not found',
#  'Klippan': 'Not found',
#  'Klöverträsk D': 'Not found',
#  'Knopparp D': 'Not found',
#  'Knäred D': 'Not found',
#  'Koler D': 'Not found',
#  'Kolsva D': 'Not found',
#  'Kopparberg D': 'Not found',
#  'Korsberga': 'Not found',
#  'Kramfors': 'Not found',
#  'Kristianstad': 'Not found',
#  'Kristinehamn': 'Not found',
#  'Krokshult D': 'Not found',
#  'Kråkemåla': 'Not found',
#  'Kungsberget D': 'Not found',
#  'Kungsör': 'Not found',
#  'Kusmark D': 'Not found',
#  'Kvikkjokk-Årrenjarka': 'Not found',
#  'Kypasjärvi D': 'Not found',
#  'Kyrktåsjö D': 'Not found',
#  'Källebäcken': 'Not found',
#  'Källsjö': 'Not found',
#  'Kärna': 'Not found',
#  'Kätkesuando': 'Not found',
#  'Kävsjö D': 'Not found',
#  'Kållered D': 'Not found',
#  'Kölsillre': 'Not found',
#  'Laholm D': 'Not found',
#  'Lainio': 'Not found',
#  'Landskrona D': 'Not found',
#  'Landsort': 'Not found',
#  'Lanna': 'Not found',
#  'Lannavaara D': 'Not found',
#  'Latikberg D': 'Not found',
#  'Leksand': 'Not found',
#  'Lesjöfors D': 'Not found',
#  'Lessebo': 'Not found',
#  'Letafors D': 'Not found',
#  'Lidhult D': 'Not found',
#  'Lidköping': 'Not found',
#  'Lillhamra D': 'Not found',
#  'Linhult D': 'Not found',
#  'Linköping': 'Not found',
#  'Malmslätt': 'Not found',
#  'Ljugarn D': 'Not found',
#  'Ljungby D': 'Not found',
#  'Ljusdals-Valsjön': 'Not found',
#  'Ljusnedal': 'Not found',
#  'Lobonäs D': 'Not found',
#  'Los D': 'Not found',
#  'Louisefred': 'Not found',
#  'Ludvika': 'Not found',
#  'Luleå-Bergnäset': 'Not found',
#  'Luleå Flygplats': 'Not found',
#  'Lund': 'Not found',
#  'Lundsjön': 'Not found',
#  'Lyckeby': 'Not found',
#  'Lysekil D': 'Not found',
#  'Långan D': 'Not found',
#  'Löten D': 'Not found',
#  'Löttorp D': 'Not found',
#  'Lövberga D': 'Not found',
#  'Lövestad': 'Not found',
#  'Lövånger': 'Not found',
#  'Malkälen D': 'Not found',
#  'Malmberget': 'Not found',
#  'Malmbäck D': 'Not found',
#  'Malungsfors': 'Not found',
#  'Malå': 'Not found',
#  'Marby D': 'Not found',
#  'Marbäck D': 'Not found',
#  'Mariefred': 'Not found',
#  'Mariestad': 'Not found',
#  'Markaryd': 'Not found',
#  'Markusvinsa': 'Not found',
#  'Mjölkbäcken': 'Not found',
#  'Moheda D': 'Not found',
#  'Mollsjönäs D': 'Not found',
#  'Mosekälla': 'Not found',
#  'Moskosel': 'Not found',
#  'Motala': 'Not found',
#  'Multrå D': 'Not found',
#  'Munka-Ljungby D': 'Not found',
#  'Murjek D': 'Not found',
#  'Myckelgensjö': 'Not found',
#  'Myre': 'Not found',
#  'Myskelåsen D': 'Not found',
#  'Mälgåsen D': 'Not found',
#  'Mästerby': 'Not found',
#  'Mångsbodarna': 'Not found',
#  'Mönsterås D': 'Not found',
#  'Mörbylånga': 'Not found',
#  'Mörsil': 'Not found',
#  'Nianfors': 'Not found',
#  'Nobynäs D': 'Not found',
#  'Nora-Östanö D': 'Not found',
#  'Norberg': 'Not found',
#  'Nordanbäck D': 'Not found',
#  'Nordanås': 'Not found',
#  'Norderön': 'Not found',
#  'Nornäs D': 'Not found',
#  'Norra Möckleby D': 'Not found',
#  'Norra Ströö': 'Not found',
#  'Norra Vi D': 'Not found',
#  'Norrby S': 'Not found',
#  'Norrköping-SMHI': 'Not found',
#  'Norrveda': 'Not found',
#  'Norsborg 2': 'Not found',
#  'Nyhammar': 'Not found',
#  'Nyhamnsläge': 'Not found',
#  'Nyköping': 'Not found',
#  'Nynäshamn': 'Not found',
#  'Nämdö': 'Not found',
#  'Näshulta': 'Not found',
#  'Näsåker': 'Not found',
#  'Nävelsjö': 'Not found',
#  'Ockelbo': 'Not found',
#  'Olastorp': 'Not found',
#  'Olofström': 'Not found',
#  'Omberg D': 'Not found',
#  'Onsala D': 'Not found',
#  'Orrefors D': 'Not found',
#  'Orsa D': 'Not found',
#  'Osby': 'Not found',
#  'Oskarshamn': 'Not found',
#  'Oxelösund': 'Not found',
#  'Parakka': 'Not found',
#  'Parkajoki': 'Not found',
#  'Persberg': 'Not found',
#  'Piteå': 'Not found',
#  'Pjätteryd': 'Not found',
#  'Prästkulla': 'Not found',
#  'Puottaure': 'Not found',
#  'Ramsjöholm': 'Not found',
#  'Reftele D': 'Not found',
#  'Remningstorp': 'Not found',
#  'Resele': 'Not found',
#  'Rickleå': 'Not found',
#  'Riddarhyttan': 'Not found',
#  'Rissna D': 'Not found',
#  'Ronneby-Bredåkra': 'Not found',
#  'Rossö': 'Not found',
#  'Rossön': 'Not found',
#  'Rusksele D': 'Not found',
#  'Räfsebo D': 'Not found',
#  'Rödupp': 'Not found',
#  'Rörastrand': 'Not found',
#  'Rörvik D': 'Not found',
#  'Saarikoski D': 'Not found',
#  'Sadiliden': 'Not found',
#  'Sadjem D': 'Not found',
#  'Saittarova D': 'Not found',
#  'Sala': 'Not found',
#  'Sanda': 'Not found',
#  'Sandhamn D': 'Not found',
#  'Sandhem': 'Not found',
#  'Segerstad': 'Not found',
#  'Sidsjö D': 'Not found',
#  'Silvergruvan': 'Not found',
#  'Simeå': 'Not found',
#  'Sjöbo D': 'Not found',
#  'Sjötofta D': 'Not found',
#  'Skara': 'Not found',
#  'Skattungbyn D': 'Not found',
#  'Skedemosse D': 'Not found',
#  'Skeppshult D': 'Not found',
#  'Skröven D': 'Not found',
#  'Sköldinge': 'Not found',
#  'Skövde': 'Not found',
#  'Slättån': 'Not found',
#  'Sollefteå': 'Not found',
#  'Sorsele': 'Not found',
#  'Spannarboda D': 'Not found',
#  'Stehag': 'Not found',
#  'Stiby': 'Not found',
#  'Stockholm': 'Not found',
#  'Stora Skedvi': 'Not found',
#  'Storbron': 'Not found',
#  'Stordalen-Midlanda D': 'Not found',
#  'Storlien-Storvallen': 'Not found',
#  'Stormyra': 'Not found',
#  'Strängnäs-Vansö': 'Not found',
#  'Strömsund-Edet D': 'Not found',
#  'Ställdalen': 'Not found',
#  'Stångsmåla D': 'Not found',
#  'Stöllet D': 'Not found',
#  'Sunneränga': 'Not found',
#  'Svaneholm D': 'Not found',
#  'Svanstein': 'Not found',
#  'Svappavaara': 'Not found',
#  'Svartberget D': 'Not found',
#  'Svedjelandet': 'Not found',
#  'Sveg-Eggarna': 'Not found',
#  'Svenska Högarna': 'Not found',
#  'Sya': 'Not found',
#  'Säffle': 'Not found',
#  'Särna D': 'Not found',
#  'Sätila': 'Not found',
#  'Sävsjö': 'Not found',
#  'Sågen D': 'Not found',
#  'Såtenäs': 'Not found',
#  'Söderala D': 'Not found',
#  'Söderby-Karlsäng D': 'Not found',
#  'Söderbärke D': 'Not found',
#  'Söderköping': 'Not found',
#  'Södersel D': 'Not found',
#  'Södertälje': 'Not found',
#  'Södra Vi D': 'Not found',
#  'Sölje D': 'Not found',
#  'Söne': 'Not found',
#  'Sörbytorp': 'Not found',
#  'Talliden': 'Not found',
#  'Talljärv D': 'Not found',
#  'Tavelsjö D': 'Not found',
#  'Tingsryd-Degerhaga': 'Not found',
#  'Tjällmo D': 'Not found',
#  'Torsåker D': 'Not found',
#  'Traneberg': 'Not found',
#  'Trelleborg': 'Not found',
#  'Trolleboda D': 'Not found',
#  'Tryserum D': 'Not found',
#  'Trängslet': 'Not found',
#  'Trökörna': 'Not found',
#  'Tullus D': 'Not found',
#  'Tvingelshed': 'Not found',
#  'Tyllinge': 'Not found',
#  'Tänger D': 'Not found',
#  'Tärendö D': 'Not found',
#  'Tånga': 'Not found',
#  'Tåsan': 'Not found',
#  'Töcksfors': 'Not found',
#  'Uddevalla D': 'Not found',
#  'Ullånger': 'Not found',
#  'Ulricehamn': 'Not found',
#  'Ulvsjön D': 'Not found',
#  'Umeå-Röbäcksdalen': 'Not found',
#  'Ungsberg': 'Not found',
#  'Uppsala': 'Not found',
#  'Vadstena D': 'Not found',
#  'Vagnhärad D': 'Not found',
#  'Vallbo': 'Not found',
#  'Vallentuna': 'Not found',
#  'Valsjöbyn': 'Not found',
#  'Varberg': 'Not found',
#  'Vassunda': 'Not found',
#  'Vattholma D': 'Not found',
#  'Veddige D': 'Not found',
#  'Vedum': 'Not found',
#  'Vidsel': 'Not found',
#  'Vidsel Mo': 'Not found',
#  'Vindeln-Sunnansjönäs': 'Not found',
#  'Vingåker D': 'Not found',
#  'Virserum-Rödmossa': 'Not found',
#  'Visby D': 'Not found',
#  'Vittinge': 'Not found',
#  'Vomb': 'Not found',
#  'Vrena': 'Not found',
#  'Vuollerim': 'Not found',
#  'Vällnora D': 'Not found',
#  'Vänersborg': 'Not found',
#  'Vänge': 'Not found',
#  'Vännäs D': 'Not found',
#  'Värmlandsnäs-Ekenäs D': 'Not found',
#  'Väse D': 'Not found',
#  'Västerhaninge': 'Not found',
#  'Västermo': 'Not found',
#  'Västerås': 'Not found',
#  'Västland': 'Not found',
#  'Västvalla': 'Not found',
#  'Våmhus D': 'Not found',
#  'Vånga D': 'Not found',
#  'Vårgårda D': 'Not found',
#  'Ystad': 'Not found',
#  'Ytterberg D': 'Not found',
#  'Ytterhogdal': 'Not found',
#  'Ytterrissjö D': 'Not found',
#  'Ytterselö D': 'Not found',
#  'Zinkgruvan': 'Not found',
#  'Älgarås D': 'Not found',
#  'Älghult': 'Not found',
#  'Älvkarleby D': 'Not found',
#  'Åby': 'Not found',
#  'Åda': 'Not found',
#  'Åhus': 'Not found',
#  'Åkroken D': 'Not found',
#  'Åminne D': 'Not found',
#  'Ånge-Parteboda D': 'Not found',
#  'Ånimskog': 'Not found',
#  'Årjäng': 'Not found',
#  'Åsarna D': 'Not found',
#  'Åsele': 'Not found',
#  'Åsnorrbodarna': 'Not found',
#  'Åtorp': 'Not found',
#  'Ödeshög D': 'Not found',
#  'Ölands norra udde': 'Not found',
#  'Ön': 'Not found',
#  'Öningaryd': 'Not found',
#  'Örebro D': 'Not found',
#  'Örkelljunga': 'Not found',
#  'Örnsköldsvik': 'Not found',
#  'Östanvik': 'Not found',
#  'Österfärnebo': 'Not found',
#  'Östervåla D': 'Not found',
#  'Östmark-Åsarna': 'Not found',
#  'Östra Husby D': 'Not found',
#  'Övertorneå': 'Not found',
#  'Övre Soppero': 'Not found'}

# %%
#Detta är ortbok, men som vi också har fyllt i manuellt

# %%
ortbok_manuell = {'Abisko': 'Norrbottens län',
 'Abraur': 'Not found',
 'Adak': 'Västerbottens län',
 'Alingsås D': 'Västra Götalands län',
 'Almdalen': 'Not found',
 'Ankarsrum D': 'Kalmar län',
 'Ankarvattnet D': 'Not found',
 'Arjeplog-Myrheden D': 'Not found',
 'Asker D': 'Not found',
 'Askim D': 'Not found',
 'Aspa D': 'Not found',
 'Aspeå': 'Västerbottens län',
 'Austers D': 'Not found',
 'Avasjö-Borgafjäll D': 'Not found',
 'Avesta': 'Dalarnas län',
 'Backe D': 'Not found',
 'Bakarebo D': 'Not found',
 'Balsjö D': 'Västerbottens län',
 'Baramossa': 'Not found',
 'Bastansjö D': 'Not found',
 'Bengtsfors': 'Västra Götalands län',
 'Berg': 'Not found',
 'Bergsjö': 'Gävleborgs län',
 'Bispgården': 'Not found',
 'Bjursås': 'Dalarnas län',
 'Bjärnum D': 'Skåne län',
 'Björklinge D': 'Uppsala län',
 'Björkudden': 'Not found',
 'Björkvik D': 'Södermanlands län',
 'Blaiken D': 'Not found',
 'Bollebygd': 'Västra Götalands län',
 'Bollnäs D': 'Gävleborgs län',
 'Borgvattnet D': 'Jämtlands län',
 'Borlänge D': 'Dalarnas län',
 'Borås': 'Västra Götalands län',
 'Bottnaryd': 'Jönköpings län',
 'Bottnen': 'Not found',
 'Bredbyn D': 'Västernorrlands län',
 'Bromölla': 'Skåne län',
 'Brovallen': 'Not found',
 'Brände': 'Not found',
 'Brännberg D': 'Not found',
 'Brännforssund': 'Not found',
 'Brösarp D': 'Skåne län',
 'Bygdsiljum D': 'Västerbottens län',
 'Bäckefors': 'Västra Götalands län',
 'Bäverträsk': 'Not found',
 'Börrum D': 'Östergötlands län',
 'Charlottenberg': 'Värmlands län',
 'Dala-Järna D': 'Dalarnas län',
 'Dalarö D': 'Stockholms län',
 'Dalstorp': 'Västra Götalands län',
 'Degeberga D': 'Skåne län',
 'Degerfors D': 'Örebro län',
 'Delsbo': 'Gävleborgs län',
 'Digernäset D': 'Not found',
 'Djursätra': 'Not found',
 'Djurö D': 'Not found',
 'Dödre': 'Jämtlands län',
 'Ed D': 'Not found',
 'Edevik': 'Not found',
 'Eftra D': 'Hallands län',
 'Emmaboda D': 'Kalmar län',
 'Enköping': 'Uppsala län',
 'Eringsboda D': 'Blekinge län',
 'Eskilstuna': 'Södermanlands län',
 'Esrange': 'Not found',
 'Fagerhult D': 'Not found',
 'Falköping-Valtorp D': 'Not found',
 'Falsterbo': 'Skåne län',
 'Falun-Lugnet': 'Not found',
 'Finnbacka D': 'Not found',
 'Finspång': 'Östergötlands län',
 'Fjällsjönäs': 'Not found',
 'Forse': 'Västernorrlands län',
 'Fotskäl D': 'Västra Götalands län',
 'Fredriksberg': 'Dalarnas län',
 'Fridlevstad D': 'Blekinge län',
 'Frostviken D': 'Not found',
 'Frändesta': 'Västmanlands län',
 'Fägre D': 'Västra Götalands län',
 'Fågelberget D': 'Not found',
 'Fågelsjö D': 'Not found',
 'Gargnäs D': 'Västerbottens län',
 'Gendalen': 'Västra Götalands län',
 'Gesunda D': 'Dalarnas län',
 'Gillastig': 'Not found',
 'Glindran': 'Not found',
 'Glommersträsk': 'Norrbottens län',
 'Godegård D': 'Östergötlands län',
 'Granhed D': 'Not found',
 'Granhult': 'Not found',
 'Granö D': 'Västerbottens län',
 'Grebbeshult': 'Not found',
 'Grythyttan': 'Örebro län',
 'Gräsås D': 'Värmlands län',
 'Grönliden': 'Not found',
 'Gullspång': 'Västra Götalands län',
 'Gustavsfors': 'Västra Götalands län',
 'Gustorp D': 'Not found',
 'Gästrike-Hammarby D': 'Gävleborgs län',
 'Gävle-Åbyggeby': 'Not found',
 'Gåltjärn': 'Not found',
 'Hallstaberg': 'Not found',
 'Halmstad': 'Hallands län',
 'Hammarö': 'Not found',
 'Hammerdal D': 'Jämtlands län',
 'Handsjön D': 'Not found',
 'Haparanda D': 'Norrbottens län',
 'Harads D': 'Norrbottens län',
 'Hattsjöbäcken D': 'Not found',
 'Heden': 'Not found',
 'Hedesunda': 'Gävleborgs län',
 'Hedeviken': 'Jämtlands län',
 'Hejnum': 'Not found',
 'Hellerö': 'Not found',
 'Hemse': 'Gotlands län',
 'Hennan D': 'Not found',
 'Henån': 'Västra Götalands län',
 'Herrljunga D': 'Västra Götalands län',
 'Hestra D': 'Not found',
 'Hid D': 'Not found',
 'Hillersboda': 'Dalarnas län',
 'Hillsand': 'Jämtlands län',
 'Hinshult': 'Not found',
 'Hjo': 'Västra Götalands län',
 'Hjortkvarn D': 'Örebro län',
 'Hoburg D': 'Not found',
 'Hofors': 'Gävleborgs län',
 'Holmbo D': 'Not found',
 'Holmfors D': 'Not found',
 'Holmön D': 'Not found',
 'Horred': 'Västra Götalands län',
 'Hov': 'Not found',
 'Hudiksvall': 'Gävleborgs län',
 'Hult D': 'Not found',
 'Hyltan': 'Not found',
 'Hyndevad': 'Södermanlands län',
 'Häggberget D': 'Not found',
 'Häggårda': 'Not found',
 'Hälleforsnäs D': 'Södermanlands län',
 'Härjeåsjön': 'Not found',
 'Härnebo': 'Not found',
 'Härnösand': 'Västernorrlands län',
 'Härryda': 'Västra Götalands län',
 'Härsnäs': 'Not found',
 'Hässleby D': 'Not found',
 'Håvelund': 'Not found',
 'Högboda': 'Värmlands län',
 'Högemålen D': 'Not found',
 'Höglekardalen': 'Not found',
 'Högsbo': 'Not found',
 'Höljes': 'Värmlands län',
 'Idre D': 'Dalarnas län',
 'Jarhois': 'Not found',
 'Jukkasjärvi D': 'Norrbottens län',
 'Jäckvik': 'Norrbottens län',
 'Järpströmmen': 'Not found',
 'Järvsö': 'Gävleborgs län',
 'Jönköping': 'Jönköpings län',
 'Jörn D': 'Västerbottens län',
 'Kalix D': 'Norrbottens län',
 'Kalmar D': 'Kalmar län',
 'Kalvträsk D': 'Västerbottens län',
 'Kangos D': 'Norrbottens län',
 'Karesuando': 'Norrbottens län',
 'Karlshamn': 'Blekinge län',
 'Karlskoga': 'Örebro län',
 'Karlstad-Skåre': 'Not found',
 'Karungi': 'Norrbottens län',
 'Katterjåkk': 'Not found',
 'Katterjåkk A': 'Not found',
 'Kaxås-Åflo D': 'Not found',
 'Kilafors D': 'Gävleborgs län',
 'Kilagården': 'Not found',
 'Kindsboda': 'Not found',
 'Kindsjön D': 'Not found',
 'Kiruna': 'Norrbottens län',
 'Kisa D': 'Östergötlands län',
 'Kittelfjäll D': 'Västerbottens län',
 'Klippan': 'Skåne län',
 'Klöverträsk D': 'Norrbottens län',
 'Knopparp D': 'Not found',
 'Knäred D': 'Hallands län',
 'Koler D': 'Norrbottens län',
 'Kolsva D': 'Västmanlands län',
 'Kopparberg D': 'Örebro län',
 'Korsberga': 'Not found',
 'Kramfors': 'Västernorrlands län',
 'Kristianstad': 'Skåne län',
 'Kristinehamn': 'Värmlands län',
 'Krokshult D': 'Not found',
 'Kråkemåla': 'Not found',
 'Kungsberget D': 'Not found',
 'Kungsör': 'Västmanlands län',
 'Kusmark D': 'Not found',
 'Kvikkjokk-Årrenjarka': 'Not found',
 'Kypasjärvi D': 'Not found',
 'Kyrktåsjö D': 'Jämtlands län',
 'Källebäcken': 'Not found',
 'Källsjö': 'Hallands län',
 'Kärna': 'Not found',
 'Kätkesuando': 'Norrbottens län',
 'Kävsjö D': 'Jönköpings län',
 'Kållered D': 'Västra Götalands län',
 'Kölsillre': 'Västernorrlands län',
 'Laholm D': 'Hallands län',
 'Lainio': 'Norrbottens län',
 'Landskrona D': 'Skåne län',
 'Landsort': 'Not found',
 'Lanna': 'Not found',
 'Lannavaara D': 'Norrbottens län',
 'Latikberg D': 'Västerbottens län',
 'Leksand': 'Dalarnas län',
 'Lesjöfors D': 'Värmlands län',
 'Lessebo': 'Kronobergs län',
 'Letafors D': 'Värmlands län',
 'Lidhult D': 'Kronobergs län',
 'Lidköping': 'Västra Götalands län',
 'Lillhamra D': 'Not found',
 'Linhult D': 'Not found',
 'Linköping': 'Östergötlands län',
 'Malmslätt': 'Östergötlands län',
 'Ljugarn D': 'Gotlands län',
 'Ljungby D': 'Kronobergs län',
 'Ljusdals-Valsjön': 'Not found',
 'Ljusnedal': 'Jämtlands län',
 'Lobonäs D': 'Not found',
 'Los D': 'Gävleborgs län',
 'Louisefred': 'Not found',
 'Ludvika': 'Dalarnas län',
 'Luleå-Bergnäset': 'Not found',
 'Luleå Flygplats': 'Norrbottens län',
 'Lund': 'Skåne län',
 'Lundsjön': 'Not found',
 'Lyckeby': 'Not found',
 'Lysekil D': 'Västra Götalands län',
 'Långan D': 'Not found',
 'Löten D': 'Not found',
 'Löttorp D': 'Kalmar län',
 'Lövberga D': 'Jämtlands län',
 'Lövestad': 'Skåne län',
 'Lövånger': 'Västerbottens län',
 'Malkälen D': 'Not found',
 'Malmberget': 'Norrbottens län',
 'Malmbäck D': 'Jönköpings län',
 'Malungsfors': 'Dalarnas län',
 'Malå': 'Västerbottens län',
 'Marby D': 'Not found',
 'Marbäck D': 'Västra Götalands län',
 'Mariefred': 'Södermanlands län',
 'Mariestad': 'Västra Götalands län',
 'Markaryd': 'Kronobergs län',
 'Markusvinsa': 'Norrbottens län',
 'Mjölkbäcken': 'Not found',
 'Moheda D': 'Kronobergs län',
 'Mollsjönäs D': 'Not found',
 'Mosekälla': 'Not found',
 'Moskosel': 'Norrbottens län',
 'Motala': 'Östergötlands län',
 'Multrå D': 'Västernorrlands län',
 'Munka-Ljungby D': 'Skåne län',
 'Murjek D': 'Norrbottens län',
 'Myckelgensjö': 'Västernorrlands län',
 'Myre': 'Jämtlands län',
 'Myskelåsen D': 'Not found',
 'Mälgåsen D': 'Not found',
 'Mästerby': 'Gotlands län',
 'Mångsbodarna': 'Dalarnas län',
 'Mönsterås D': 'Kalmar län',
 'Mörbylånga': 'Kalmar län',
 'Mörsil': 'Jämtlands län',
 'Nianfors': 'Gävleborgs län',
 'Nobynäs D': 'Not found',
 'Nora-Östanö D': 'Not found',
 'Norberg': 'Västmanlands län',
 'Nordanbäck D': 'Not found',
 'Nordanås': 'Västernorrlands län',
 'Norderön': 'Not found',
 'Nornäs D': 'Dalarnas län',
 'Norra Möckleby D': 'Not found',
 'Norra Ströö': 'Not found',
 'Norra Vi D': 'Not found',
 'Norrby S': 'Not found',
 'Norrköping-SMHI': 'Not found',
 'Norrveda': 'Not found',
 'Norsborg 2': 'Stockholms län',
 'Nyhammar': 'Dalarnas län',
 'Nyhamnsläge': 'Skåne län',
 'Nyköping': 'Södermanlands län',
 'Nynäshamn': 'Stockholms län',
 'Nämdö': 'Stockholms län',
 'Näshulta': 'Södermanlands län',
 'Näsåker': 'Västernorrlands län',
 'Nävelsjö': 'Jönköpings län',
 'Ockelbo': 'Gävleborgs län',
 'Ockelbo 1': 'Gävleborgs län',
 'Olastorp': 'Not found',
 'Olofström': 'Blekinge län',
 'Omberg D': 'Not found',
 'Onsala D': 'Hallands län',
 'Orrefors D': 'Kalmar län',
 'Orsa D': 'Dalarnas län',
 'Osby': 'Skåne län',
 'Oskarshamn': 'Kalmar län',
 'Oxelösund': 'Södermanlands län',
 'Parakka': 'Norrbottens län',
 'Parkajoki': 'Norrbottens län',
 'Persberg': 'Värmlands län',
 'Piteå': 'Norrbottens län',
 'Pjätteryd': 'Kronobergs län',
 'Prästkulla': 'Not found',
 'Puottaure': 'Not found',
 'Ramsjöholm': 'Not found',
 'Reftele D': 'Jönköpings län',
 'Remningstorp': 'Not found',
 'Resele': 'Västernorrlands län',
 'Rickleå': 'Not found',
 'Riddarhyttan': 'Västmanlands län',
 'Rissna D': 'Jämtlands län',
 'Ronneby-Bredåkra': 'Not found',
 'Rossö': 'Västra Götalands län',
 'Rossön': 'Jämtlands län',
 'Rusksele D': 'Västerbottens län',
 'Räfsebo D': 'Not found',
 'Rödupp': 'Not found',
 'Rörastrand': 'Not found',
 'Rörvik D': 'Not found',
 'Saarikoski D': 'Not found',
 'Sadiliden': 'Not found',
 'Sadjem D': 'Not found',
 'Saittarova D': 'Norrbottens län',
 'Sala': 'Västmanlands län',
 'Sanda': 'Not found',
 'Sandhamn D': 'Stockholms län',
 'Segerstad': 'Not found',
 'Sidsjö D': 'Not found',
 'Silvergruvan': 'Not found',
 'Simeå': 'Gävleborgs län',
 'Sjöbo D': 'Skåne län',
 'Sjötofta D': 'Västra Götalands län',
 'Skara': 'Västra Götalands län',
 'Skattungbyn D': 'Dalarnas län',
 'Skedemosse D': 'Not found',
 'Skeppshult D': 'Jönköpings län',
 'Skröven D': 'Not found',
 'Sköldinge': 'Södermanlands län',
 'Skövde': 'Västra Götalands län',
 'Slättån': 'Not found',
 'Sollefteå': 'Västernorrlands län',
 'Sorsele': 'Västerbottens län',
 'Spannarboda D': 'Örebro län',
 'Stehag': 'Skåne län',
 'Stiby': 'Not found',
 'Stockholm-Observatoriekullen': 'Not found',
 'Stora Skedvi': 'Not found',
 'Storbron': 'Not found',
 'Stordalen-Midlanda D': 'Not found',
 'Storlien-Storvallen': 'Not found',
 'Stormyra': 'Not found',
 'Strängnäs-Vansö': 'Not found',
 'Strömsund-Edet D': 'Not found',
 'Ställdalen': 'Örebro län',
 'Stångsmåla D': 'Not found',
 'Stöllet D': 'Värmlands län',
 'Sunneränga': 'Not found',
 'Svaneholm D': 'Not found',
 'Svanstein': 'Norrbottens län',
 'Svappavaara': 'Norrbottens län',
 'Svartberget D': 'Not found',
 'Svedjelandet': 'Not found',
 'Sveg-Eggarna': 'Not found',
 'Svenska Högarna': 'Not found',
 'Sya': 'Östergötlands län',
 'Säffle': 'Värmlands län',
 'Särna D': 'Dalarnas län',
 'Sätila': 'Västra Götalands län',
 'Sävsjö': 'Jönköpings län',
 'Sågen D': 'Not found',
 'Såtenäs': 'Västra Götalands län',
 'Söderala D': 'Gävleborgs län',
 'Söderby-Karlsäng D': 'Not found',
 'Söderbärke D': 'Dalarnas län',
 'Söderköping': 'Östergötlands län',
 'Södersel D': 'Not found',
 'Södertälje': 'Stockholms län',
 'Södra Vi D': 'Not found',
 'Sölje D': 'Not found',
 'Söne': 'Västra Götalands län',
 'Sörbytorp': 'Not found',
 'Talliden': 'Not found',
 'Talljärv D': 'Not found',
 'Tavelsjö D': 'Västerbottens län',
 'Tingsryd-Degerhaga': 'Not found',
 'Tjällmo D': 'Östergötlands län',
 'Torsåker D': 'Not found',
 'Traneberg': 'Not found',
 'Trelleborg': 'Skåne län',
 'Trolleboda D': 'Not found',
 'Tryserum D': 'Östergötlands län',
 'Trängslet': 'Not found',
 'Trökörna': 'Not found',
 'Tullus D': 'Not found',
 'Tvingelshed': 'Not found',
 'Tyllinge': 'Kalmar län',
 'Tänger D': 'Not found',
 'Tärendö D': 'Norrbottens län',
 'Tånga': 'Skåne län',
 'Tåsan': 'Not found',
 'Töcksfors': 'Värmlands län',
 'Uddevalla D': 'Västra Götalands län',
 'Ullånger': 'Västernorrlands län',
 'Ulricehamn': 'Västra Götalands län',
 'Ulvsjön D': 'Södermanlands län',
 'Umeå-Röbäcksdalen': 'Västerbottens län',
 'Ungsberg': 'Kalmar län',
 'Uppsala': 'Uppsala län',
 'Uppsala Aut': 'Uppsala län',
 'Vadstena D': 'Östergötlands län',
 'Vagnhärad D': 'Södermanlands län',
 'Vallbo': 'Jämtlands län',
 'Vallentuna': 'Stockholms län',
 'Valsjöbyn': 'Jämtlands län',
 'Varberg': 'Hallands län',
 'Vassunda': 'Uppsala län',
 'Vattholma D': 'Uppsala län',
 'Veddige D': 'Hallands län',
 'Vedum': 'Västra Götalands län',
 'Vidsel': 'Norrbottens län',
 'Vidsel Mo': 'Norrbottens län',
 'Vindeln-Sunnansjönäs': 'Västerbottens län',
 'Vingåker D': 'Södermanlands län',
 'Virserum-Rödmossa': 'Kalmar län',
 'Visby D': 'Gotlands län',
 'Vittinge': 'Uppsala län',
 'Vomb': 'Skåne län',
 'Vrena': 'Södermanlands län',
 'Vuollerim': 'Norrbottens län',
 'Vällnora D': 'Uppsala län',
 'Vänersborg': 'Västra Götalands län',
 'Vänge': 'Uppsala län',
 'Vännäs D': 'Västerbottens län',
 'Värmlandsnäs-Ekenäs D': 'Not found',
 'Väse D': 'Värmlands län',
 'Västerhaninge': 'Stockholms län',
 'Västermo': 'Södermanlands län',
 'Västerås': 'Västmanlands län',
 'Västland': 'Uppsala län',
 'Västvalla': 'Örebro län',
 'Våmhus D': 'Dalarnas län',
 'Vånga D': 'Östergötalands län',
 'Vårgårda D': 'Västra Götalands län',
 'Ystad': 'Skåne län',
 'Ytterberg D': 'Jämtlands län',
 'Ytterhogdal': 'Jämtlands län',
 'Ytterrissjö D': 'Västerbottens län',
 'Ytterselö D': 'Södermanlands län',
 'Zinkgruvan': 'Örebro län',
 'Älgarås D': 'Västra Götalands län',
 'Älghult': 'Kronobergs län',
 'Älvkarleby D': 'Uppsala län',
 'Åby': 'Östergötlands län',
 'Åda': 'Södermanlands län',
 'Åhus': 'Skåne län',
 'Åkroken D': 'Västernorrlands',
 'Åminne D': 'Gotlands län',
 'Ånge-Parteboda D': 'Västernorrlands län',
 'Ånimskog': 'Västra Götalands län',
 'Årjäng': 'Värmlands län',
 'Åsarna D': 'Jämtlands län',
 'Åsele': 'Västerbottens län',
 'Åsnorrbodarna': 'Gävleborgs län',
 'Åtorp': 'Örebro län',
 'Ödeshög D': 'Östergötlands län',
 'Ölands norra udde': 'Kalmar län',
 'Ön': 'Skåne län',
 'Öningaryd': 'Kalmar län',
 'Örebro D': 'Örebro län',
 'Örkelljunga': 'Skåne län',
 'Örnsköldsvik': 'Västernorrlands län',
 'Östanvik': 'Dalarnas län',
 'Österfärnebo': 'Gävleborgs län',
 'Östervåla D': 'Uppsala län',
 'Östmark-Åsarna': 'Värmlands län',
 'Östra Husby D': 'Östergötlands län',
 'Övertorneå': 'Norrbottens län',
 'Övre Soppero': 'Norrbottens län',
'Hallstaberg': "Not found",
 'Katterjåkk A': "Not found",
 'Ockelbo 1': "Not found",
 'Stockholm-Observatoriekullen': "Not found",
 'Uppsala Aut': "Not found"}

# %%
ne_url = "https://www.ne.se/uppslagsverk/encyklopedi/lång/"

# %%
def scrape_ne(ortbok_manuell):
    for ort in ortbok_manuell:

        if ortbok_manuell[ort]=='Not found':
            new_ort = ort.lower()
            end_char = None
            if ort[-1]=='D':
                new_ort = ort[:-1].lower()

            r = requests.get(url = ne_url+new_ort, timeout=5)

            if r.status_code == 200:

               # print("YEAH")
                soup = BeautifulSoup(r.text)

                try:
                    text = soup.find(class_="def").text

                    end_char = text.find("län)")

                    if end_char == -1:
                        raise Exception("No region found")
                    else:
                        end_char = end_char+3

                    start_char = None
                    for i in range(end_char, 0, -1):
                        if text[i] == '(':
                            start_char = i+1

                    region = text[start_char:end_char]
                    ortbok_manuell[ort]=region
                    print(ort+" -  "+region)
                except:
                    print("Not found")
    return ortbok_manuell

# %%
ne_ortbok = scrape_ne(ortbok)
# Out:
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found
# Not found

# %%
ne_backupp = ortbok_manuell

# %%
import json

# %%
def scrape_open_street(ortbok_manuell):
    for ort in ortbok_manuell:

        if ortbok_manuell[ort]=='Not found':
            new_ort = ort.lower()
            end_char = None
            if ort[-1]=='D':
                new_ort = ort[:-1].lower().strip(' ')

            opensURL = "https://nominatim.openstreetmap.org/search.php?q="+new_ort+"&polygon_geojson=1&countrycodes=se&format=jsonv2"
            r = requests.get(url = opensURL, timeout=5)

            if r.status_code == 200:
                json_data = r.text


                data = json.loads(json_data)

                # Print the type of data variable
                print("Type:", type(data))
                print("Size: "+str(len(data)))

                if len(data)==0:
                    continue;

                new_data = []

                if type(data) == list:
                    for loc in data:
                       # print("Name: "+loc["display_name"])
                       # print("Type: "+loc["type"])
                        _ = loc["display_name"].split(',')
                        name = _[0]
                        region = _[2][1:]
                        for n in _:
                            if n.rfind("län") > -1:
                                region = n.strip(' ')


                        new_data.append({"Name": name, "Region":region, "Type": loc["type"], "Points": 0 })



                    for loc in new_data:
                        if loc["Type"] == "isolated_dwelling":
                            loc["Points"] = loc["Points"]+1
                        if loc["Name"].lower() != new_ort.lower():
                            loc["Points"] = loc["Points"]-2

                    loc_winner = new_data[0]
                    points = loc_winner["Points"]
                    for loc in new_data:
                        if loc["Points"] > points:
                            loc_winner = loc

                    print(loc_winner)

                    ortbok_manuell[ort]=loc_winner["Region"]

                    print(new_ort+" -  "+loc_winner["Region"])

    return ortbok_manuell

# %%
def dic_to_df(list_of_dic, c):
    key_column = []
    value_column = []
    for key in list_of_dic:
        value = list_of_dic[key]
        key_column.append(key)
        value_column.append(value)
    new_df=pd.DataFrame(list(zip(key_column, value_column)), columns=c)
    return new_df

# %%
ne_ops_ort = scrape_open_street(ne_ortbok)
# Out:
# Type: <class 'list'>
# Size: 1
# {'Name': 'Adak', 'Region': 'Västerbottens län', 'Type': 'village', 'Points': 0}
# adak -  Västerbottens län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Almdalen', 'Region': 'Jämtlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# almdalen -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Ankarvattnet', 'Region': 'Jämtlands län', 'Type': 'water', 'Points': 0}
# ankarvattnet -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Myrheden', 'Region': 'Norrbottens län', 'Type': 'isolated_dwelling', 'Points': -1}
# arjeplog-myrheden -  Norrbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Asker', 'Region': 'Stockholms län', 'Type': 'isolated_dwelling', 'Points': 1}
# asker -  Stockholms län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Aspa', 'Region': 'Jönköpings län', 'Type': 'isolated_dwelling', 'Points': 1}
# aspa -  Jönköpings län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Aspeå', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# aspeå -  Västerbottens län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Austers', 'Region': 'Gotlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# austers -  Gotlands län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Avasjö kapell', 'Region': 'Västerbottens län', 'Type': 'place_of_worship', 'Points': -2}
# avasjö-borgafjäll -  Västerbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Bakarebo', 'Region': 'Östergötlands län', 'Type': 'hamlet', 'Points': 0}
# bakarebo -  Östergötlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Balsjö', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# balsjö -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Baramossa', 'Region': 'Hallands län', 'Type': 'isolated_dwelling', 'Points': 1}
# baramossa -  Hallands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Bastansjö', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# bastansjö -  Västerbottens län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Berg', 'Region': 'Västernorrlands län', 'Type': 'hamlet', 'Points': 0}
# berg -  Västernorrlands län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Bispgården', 'Region': 'Jämtlands län', 'Type': 'village', 'Points': 0}
# bispgården -  Jämtlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Björkudden', 'Region': 'Stockholms län', 'Type': 'isolated_dwelling', 'Points': 1}
# björkudden -  Stockholms län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Blaiken', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# blaiken -  Västerbottens län
# Type: <class 'list'>
# Size: 8
# {'Name': 'Bottnen', 'Region': 'Jämtlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# bottnen -  Jämtlands län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Brovallen', 'Region': 'Dalarnas län', 'Type': 'hamlet', 'Points': 0}
# brovallen -  Dalarnas län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Brände', 'Region': 'Västerbottens län', 'Type': 'isolated_dwelling', 'Points': 1}
# brände -  Västerbottens län
# Type: <class 'list'>
# Size: 7
# {'Name': 'Brännberg', 'Region': 'Västerbottens län', 'Type': 'isolated_dwelling', 'Points': 1}
# brännberg -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Brännforssund', 'Region': 'Västerbottens län', 'Type': 'isolated_dwelling', 'Points': 1}
# brännforssund -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Bäverträsk', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# bäverträsk -  Västerbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Dala-Järna', 'Region': 'Dalarnas län', 'Type': 'technical_station', 'Points': 0}
# dala-järna -  Dalarnas län
# Type: <class 'list'>
# Size: 0
# Type: <class 'list'>
# Size: 2
# {'Name': 'Djursätra', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': 0}
# djursätra -  Västra Götalands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Dödre', 'Region': 'Jämtlands län', 'Type': 'hamlet', 'Points': 0}
# dödre -  Jämtlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Ed', 'Region': 'Västra Götalands län', 'Type': 'town', 'Points': 0}
# ed -  Västra Götalands län
# Type: <class 'list'>
# Size: 0
# Type: <class 'list'>
# Size: 2
# {'Name': 'Esrange', 'Region': 'Norrbottens län', 'Type': 'tower', 'Points': 0}
# esrange -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Valtorp', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': -2}
# falköping-valtorp -  Västra Götalands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Falsterbo', 'Region': 'Skåne län', 'Type': 'island', 'Points': 0}
# falsterbo -  Skåne län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Lugnet', 'Region': 'Dalarnas län', 'Type': 'neighbourhood', 'Points': -2}
# falun-lugnet -  Dalarnas län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Finnbacka', 'Region': 'Dalarnas län', 'Type': 'hamlet', 'Points': 0}
# finnbacka -  Dalarnas län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Fjällsjönäs', 'Region': 'Västerbottens län', 'Type': 'isolated_dwelling', 'Points': 1}
# fjällsjönäs -  Västerbottens län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Forse', 'Region': 'Gotlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# forse -  Gotlands län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Frändesta', 'Region': 'Västmanlands län', 'Type': 'hamlet', 'Points': 0}
# frändesta -  Västmanlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Fågelberget', 'Region': 'Södermanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# fågelberget -  Södermanlands län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Fågelsjö', 'Region': 'Västmanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# fågelsjö -  Västmanlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Gendalen', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': 0}
# gendalen -  Västra Götalands län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Gillastig', 'Region': 'Skåne län', 'Type': 'locality', 'Points': 0}
# gillastig -  Skåne län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Glindran', 'Region': 'Södermanlands län', 'Type': 'hamlet', 'Points': 0}
# glindran -  Södermanlands län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Nya Granhed', 'Region': 'Södermanlands län', 'Type': 'isolated_dwelling', 'Points': -1}
# granhed -  Södermanlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Granhult', 'Region': 'Östergötlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# granhult -  Östergötlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Grebbeshult', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': 0}
# grebbeshult -  Västra Götalands län
# Type: <class 'list'>
# Size: 6
# {'Name': 'Gräsås', 'Region': 'Västra Götalands län', 'Type': 'isolated_dwelling', 'Points': 1}
# gräsås -  Västra Götalands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Grönliden', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# grönliden -  Västerbottens län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Gustavsfors', 'Region': 'Södermanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# gustavsfors -  Södermanlands län
# Type: <class 'list'>
# Size: 9
# {'Name': 'Gustorp', 'Region': 'Östergötlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# gustorp -  Östergötlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Gästrike-Hammarby', 'Region': 'Gävleborgs län', 'Type': 'village', 'Points': 0}
# gästrike-hammarby -  Gävleborgs län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Åbyggeby', 'Region': 'Gävleborgs län', 'Type': 'school', 'Points': -2}
# gävle-åbyggeby -  Gävleborgs län
# Type: <class 'list'>
# Size: 6
# {'Name': 'Gåltjärn', 'Region': 'Västernorrlands län', 'Type': 'hamlet', 'Points': 0}
# gåltjärn -  Västernorrlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Handsjön', 'Region': 'Jämtlands län', 'Type': 'water', 'Points': 0}
# handsjön -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Hattsjöbäcken', 'Region': 'Västernorrlands län', 'Type': 'hamlet', 'Points': 0}
# hattsjöbäcken -  Västernorrlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Heden', 'Region': 'Västra Götalands län', 'Type': 'administrative', 'Points': 0}
# heden -  Västra Götalands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Hedeviken', 'Region': 'Jämtlands län', 'Type': 'village', 'Points': 0}
# hedeviken -  Jämtlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Hejnum hällars naturreservat', 'Region': 'Gotlands län', 'Type': 'protected_area', 'Points': -2}
# hejnum -  Gotlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Hellerö', 'Region': 'Kalmar län', 'Type': 'hamlet', 'Points': 0}
# hellerö -  Kalmar län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Hemse', 'Region': 'Gotlands län', 'Type': 'village', 'Points': 0}
# hemse -  Gotlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Hennan', 'Region': 'Gävleborgs län', 'Type': 'technical_station', 'Points': 0}
# hennan -  Gävleborgs län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Hid', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': 0}
# hid -  Västra Götalands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Hillersboda', 'Region': 'Dalarnas län', 'Type': 'hamlet', 'Points': 0}
# hillersboda -  Dalarnas län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Hillsand', 'Region': 'Jämtlands län', 'Type': 'hamlet', 'Points': 0}
# hillsand -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Hinshult', 'Region': 'Kalmar län', 'Type': 'locality', 'Points': 0}
# hinshult -  Kalmar län
# Type: <class 'list'>
# Size: 8
# {'Name': 'Holmbo', 'Region': 'Västmanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# holmbo -  Västmanlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Holmfors', 'Region': 'Norrbottens län', 'Type': 'isolated_dwelling', 'Points': 1}
# holmfors -  Norrbottens län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Holmön', 'Region': 'Västerbottens län', 'Type': 'island', 'Points': 0}
# holmön -  Västerbottens län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Hov', 'Region': 'Östergötlands län', 'Type': 'administrative', 'Points': 0}
# hov -  Östergötlands län
# Type: <class 'list'>
# Size: 6
# {'Name': 'Hudiksvall', 'Region': 'Gävleborgs län', 'Type': 'monitoring_station', 'Points': 0}
# hudiksvall -  Gävleborgs län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Hyltan', 'Region': 'Jönköpings län', 'Type': 'hamlet', 'Points': 0}
# hyltan -  Jönköpings län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Hyndevad', 'Region': 'Södermanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# hyndevad -  Södermanlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Häggberget', 'Region': 'Dalarnas län', 'Type': 'peak', 'Points': 0}
# häggberget -  Dalarnas län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Häggårda', 'Region': 'Västra Götalands län', 'Type': 'yes', 'Points': 0}
# häggårda -  Västra Götalands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Härjeåsjön', 'Region': 'Jämtlands län', 'Type': 'hamlet', 'Points': 0}
# härjeåsjön -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Härnebo', 'Region': 'Gävleborgs län', 'Type': 'hamlet', 'Points': 0}
# härnebo -  Gävleborgs län
# Type: <class 'list'>
# Size: 6
# {'Name': 'Härnösand', 'Region': 'Västernorrlands län', 'Type': 'town', 'Points': 0}
# härnösand -  Västernorrlands län
# Type: <class 'list'>
# Size: 9
# {'Name': 'Härsnäs', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': 0}
# härsnäs -  Västra Götalands län
# Type: <class 'list'>
# Size: 0
# Type: <class 'list'>
# Size: 1
# {'Name': 'Högemålen', 'Region': 'Jönköpings län', 'Type': 'hamlet', 'Points': 0}
# högemålen -  Jönköpings län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Höglekardalen', 'Region': 'Jämtlands län', 'Type': 'hamlet', 'Points': 0}
# höglekardalen -  Jämtlands län
# Type: <class 'list'>
# Size: 7
# {'Name': 'Högsbo', 'Region': 'Jönköpings län', 'Type': 'isolated_dwelling', 'Points': 1}
# högsbo -  Jönköpings län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Jarhois kapell', 'Region': 'Norrbottens län', 'Type': 'place_of_worship', 'Points': -2}
# jarhois -  Norrbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Jäkkvik', 'Region': 'Norrbottens län', 'Type': 'village', 'Points': -2}
# jäckvik -  Norrbottens län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Järpströmmen', 'Region': 'Jämtlands län', 'Type': 'river', 'Points': 0}
# järpströmmen -  Jämtlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Jörn', 'Region': 'Västerbottens län', 'Type': 'village', 'Points': 0}
# jörn -  Västerbottens län
# Type: <class 'list'>
# Size: 6
# {'Name': 'Kalmar', 'Region': 'Kronobergs län', 'Type': 'isolated_dwelling', 'Points': 1}
# kalmar -  Kronobergs län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Karlshamn', 'Region': 'Södermanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# karlshamn -  Södermanlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Skåre', 'Region': 'Värmlands län', 'Type': 'suburb', 'Points': -2}
# karlstad-skåre -  Värmlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Katterjåkk', 'Region': 'Norrbottens län', 'Type': 'stream', 'Points': 0}
# katterjåkk -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Åflo camping', 'Region': 'Jämtlands län', 'Type': 'camp_site', 'Points': -2}
# kaxås-åflo -  Jämtlands län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Kilagården', 'Region': 'Västra Götalands län', 'Type': 'isolated_dwelling', 'Points': 1}
# kilagården -  Västra Götalands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Kindsboda', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': 0}
# kindsboda -  Västra Götalands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Kindsjön', 'Region': 'Värmlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# kindsjön -  Värmlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Kisa', 'Region': 'Västra Götalands län', 'Type': 'isolated_dwelling', 'Points': 1}
# kisa -  Västra Götalands län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Kittelfjäll', 'Region': 'Västerbottens län', 'Type': 'village', 'Points': 0}
# kittelfjäll -  Västerbottens län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Knopparp', 'Region': 'Jönköpings län', 'Type': 'hamlet', 'Points': 0}
# knopparp -  Jönköpings län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Koler', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# koler -  Norrbottens län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Kristianstad', 'Region': 'Skåne län', 'Type': 'town', 'Points': 0}
# kristianstad -  Skåne län
# Type: <class 'list'>
# Size: 9
# {'Name': 'Krokshult', 'Region': 'Kronobergs län', 'Type': 'isolated_dwelling', 'Points': 1}
# krokshult -  Kronobergs län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Kråkemåla', 'Region': 'Kalmar län', 'Type': 'hamlet', 'Points': 0}
# kråkemåla -  Kalmar län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Kungsberget', 'Region': 'Gävleborgs län', 'Type': 'peak', 'Points': 0}
# kungsberget -  Gävleborgs län
# Type: <class 'list'>
# Size: 6
# {'Name': 'Kungsör', 'Region': 'Södermanlands län', 'Type': 'information', 'Points': 0}
# kungsör -  Södermanlands län
# Type: <class 'list'>
# Size: 6
# {'Name': 'Årrenjarka Fjällby', 'Region': 'Norrbottens län', 'Type': 'restaurant', 'Points': -2}
# kvikkjokk-årrenjarka -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Kypasjärv', 'Region': 'Norrbottens län', 'Type': 'village', 'Points': -2}
# kypasjärvi -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Kyrktåsjö', 'Region': 'Jämtlands län', 'Type': 'locality', 'Points': 0}
# kyrktåsjö -  Jämtlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Källebäcken', 'Region': 'Jönköpings län', 'Type': 'isolated_dwelling', 'Points': 1}
# källebäcken -  Jönköpings län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Kärna', 'Region': 'Östergötlands län', 'Type': 'administrative', 'Points': 0}
# kärna -  Östergötlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Kätkesuando', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# kätkesuando -  Norrbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Kölsillre', 'Region': 'Västernorrlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# kölsillre -  Västernorrlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Lainio', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# lainio -  Norrbottens län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Landskrona', 'Region': 'Skåne län', 'Type': 'stop', 'Points': 0}
# landskrona -  Skåne län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Landsort', 'Region': 'Södermanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# landsort -  Södermanlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Lannavaara', 'Region': 'Norrbottens län', 'Type': 'village', 'Points': 0}
# lannavaara -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Latikberg', 'Region': 'Västerbottens län', 'Type': 'village', 'Points': 0}
# latikberg -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Letafors', 'Region': 'Värmlands län', 'Type': 'hamlet', 'Points': 0}
# letafors -  Värmlands län
# Type: <class 'list'>
# Size: 9
# {'Name': 'Lillhamra', 'Region': 'Västmanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# lillhamra -  Västmanlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Linhult', 'Region': 'Hallands län', 'Type': 'isolated_dwelling', 'Points': 1}
# linhult -  Hallands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Ljugarn', 'Region': 'Gotlands län', 'Type': 'village', 'Points': 0}
# ljugarn -  Gotlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Valsjön', 'Region': 'Gävleborgs län', 'Type': 'hamlet', 'Points': -2}
# ljusdals-valsjön -  Gävleborgs län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Lobonäs', 'Region': 'Gävleborgs län', 'Type': 'hamlet', 'Points': 0}
# lobonäs -  Gävleborgs län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Louisefred', 'Region': 'Skåne län', 'Type': 'yes', 'Points': 0}
# louisefred -  Skåne län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Bergnäset', 'Region': 'Norrbottens län', 'Type': 'suburb', 'Points': -2}
# luleå-bergnäset -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Luleå Airport', 'Region': 'Norrbottens län', 'Type': 'aerodrome', 'Points': -2}
# luleå flygplats -  Norrbottens län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Lund', 'Region': 'Skåne län', 'Type': 'administrative', 'Points': 0}
# lund -  Skåne län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Lundsjön', 'Region': 'Jämtlands län', 'Type': 'hamlet', 'Points': 0}
# lundsjön -  Jämtlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Långan', 'Region': 'Jämtlands län', 'Type': 'river', 'Points': 0}
# långan -  Jämtlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Löten', 'Region': 'Jämtlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# löten -  Jämtlands län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Lövberga', 'Region': 'Stockholms län', 'Type': 'suburb', 'Points': 0}
# lövberga -  Stockholms län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Malkälen', 'Region': 'Västerbottens län', 'Type': 'isolated_dwelling', 'Points': 1}
# malkälen -  Västerbottens län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Mariestad', 'Region': 'Västra Götalands län', 'Type': 'station', 'Points': 0}
# mariestad -  Västra Götalands län
# Type: <class 'list'>
# Size: 0
# Type: <class 'list'>
# Size: 6
# {'Name': 'Mjölkbäcken', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# mjölkbäcken -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Mollsjönäs', 'Region': 'Västra Götalands län', 'Type': 'isolated_dwelling', 'Points': 1}
# mollsjönäs -  Västra Götalands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Västansjö-Mosekälla-Joeström', 'Region': 'Västerbottens län', 'Type': 'unclassified', 'Points': -2}
# mosekälla -  Västerbottens län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Moskosel', 'Region': 'Norrbottens län', 'Type': 'village', 'Points': 0}
# moskosel -  Norrbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Murjek', 'Region': 'Norrbottens län', 'Type': 'village', 'Points': 0}
# murjek -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Myckelgensjö', 'Region': 'Västernorrlands län', 'Type': 'hamlet', 'Points': 0}
# myckelgensjö -  Västernorrlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Myre', 'Region': 'Västernorrlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# myre -  Västernorrlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Myskelåsen', 'Region': 'Jämtlands län', 'Type': 'peak', 'Points': 0}
# myskelåsen -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Mälgåsen', 'Region': 'Jämtlands län', 'Type': 'hamlet', 'Points': 0}
# mälgåsen -  Jämtlands län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Mångsbodarna', 'Region': 'Dalarnas län', 'Type': 'hamlet', 'Points': 0}
# mångsbodarna -  Dalarnas län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Nianfors', 'Region': 'Gävleborgs län', 'Type': 'village', 'Points': 0}
# nianfors -  Gävleborgs län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Nobynäs', 'Region': 'Jönköpings län', 'Type': 'hamlet', 'Points': 0}
# nobynäs -  Jönköpings län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Östanö', 'Region': 'Västernorrlands län', 'Type': 'hamlet', 'Points': -2}
# nora-östanö -  Västernorrlands län
# Type: <class 'list'>
# Size: 6
# {'Name': 'Nordanbäck', 'Region': 'Dalarnas län', 'Type': 'isolated_dwelling', 'Points': 1}
# nordanbäck -  Dalarnas län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Nordanås', 'Region': 'Västernorrlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# nordanås -  Västernorrlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Norderön', 'Region': 'Jämtlands län', 'Type': 'island', 'Points': 0}
# norderön -  Jämtlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Nornäs', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': 0}
# nornäs -  Västra Götalands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Norra Möckleby', 'Region': 'Kalmar län', 'Type': 'hamlet', 'Points': 0}
# norra möckleby -  Kalmar län
# Type: <class 'list'>
# Size: 0
# Type: <class 'list'>
# Size: 1
# {'Name': 'Norra Vi', 'Region': 'Östergötlands län', 'Type': 'hamlet', 'Points': 0}
# norra vi -  Östergötlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Norrby', 'Region': 'Örebro län', 'Type': 'bus_stop', 'Points': -2}
# norrby s -  Örebro län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Sveriges meteorologiska och hydrologiska institut', 'Region': 'Östergötlands län', 'Type': 'government', 'Points': -2}
# norrköping-smhi -  Östergötlands län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Norrveda', 'Region': 'Stockholms län', 'Type': 'isolated_dwelling', 'Points': 1}
# norrveda -  Stockholms län
# Type: <class 'list'>
# Size: 7
# {'Name': 'Norsborg', 'Region': 'Uppsala län', 'Type': 'isolated_dwelling', 'Points': -1}
# norsborg 2 -  Uppsala län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Nyhamnsläge', 'Region': 'Skåne län', 'Type': 'village', 'Points': 0}
# nyhamnsläge -  Skåne län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Olastorp', 'Region': 'Värmlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# olastorp -  Värmlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Omberg', 'Region': 'Kalmar län', 'Type': 'isolated_dwelling', 'Points': 1}
# omberg -  Kalmar län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Nedre Parakka', 'Region': 'Norrbottens län', 'Type': 'village', 'Points': -2}
# parakka -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Parkajoki', 'Region': 'Norrbottens län', 'Type': 'stream', 'Points': 0}
# parkajoki -  Norrbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Prästkulla', 'Region': 'Östergötlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# prästkulla -  Östergötlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Puottaure', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# puottaure -  Norrbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Ramsjöholm', 'Region': 'Jönköpings län', 'Type': 'farm', 'Points': 0}
# ramsjöholm -  Jönköpings län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Remningstorp', 'Region': 'Västra Götalands län', 'Type': 'manor', 'Points': 0}
# remningstorp -  Västra Götalands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Rickleå', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# rickleå -  Västerbottens län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Rissna', 'Region': 'Jämtlands län', 'Type': 'village', 'Points': 0}
# rissna -  Jämtlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Bredåkra', 'Region': 'Blekinge län', 'Type': 'hamlet', 'Points': -2}
# ronneby-bredåkra -  Blekinge län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Rossö', 'Region': 'Västernorrlands län', 'Type': 'farm', 'Points': 0}
# rossö -  Västernorrlands län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Rossön', 'Region': 'Jämtlands län', 'Type': 'island', 'Points': 0}
# rossön -  Jämtlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Räfsebo', 'Region': 'Jönköpings län', 'Type': 'isolated_dwelling', 'Points': 1}
# räfsebo -  Jönköpings län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Rödupp', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# rödupp -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Röra Strand', 'Region': 'Västra Götalands län', 'Type': 'locality', 'Points': -2}
# rörastrand -  Västra Götalands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Saarikoski', 'Region': 'Norrbottens län', 'Type': 'isolated_dwelling', 'Points': 1}
# saarikoski -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Sadiliden', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# sadiliden -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Sadjem', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# sadjem -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Saittarova', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# saittarova -  Norrbottens län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Sala', 'Region': 'Västmanlands län', 'Type': 'information', 'Points': 0}
# sala -  Västmanlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Sidsjö', 'Region': 'Västernorrlands län', 'Type': 'suburb', 'Points': 0}
# sidsjö -  Västernorrlands län
# Type: <class 'list'>
# Size: 8
# {'Name': 'Silvergruvan', 'Region': 'Värmlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# silvergruvan -  Värmlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Simeå', 'Region': 'Gävleborgs län', 'Type': 'hamlet', 'Points': 0}
# simeå -  Gävleborgs län
# Type: <class 'list'>
# Size: 8
# {'Name': 'Skara', 'Region': 'Gävleborgs län', 'Type': 'isolated_dwelling', 'Points': 1}
# skara -  Gävleborgs län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Skedemosse', 'Region': 'Kalmar län', 'Type': 'farm', 'Points': 0}
# skedemosse -  Kalmar län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Skröven', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# skröven -  Norrbottens län
# Type: <class 'list'>
# Size: 7
# {'Name': 'Slättån', 'Region': 'Västernorrlands län', 'Type': 'hamlet', 'Points': 0}
# slättån -  Västernorrlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Spannarboda', 'Region': 'Örebro län', 'Type': 'hamlet', 'Points': 0}
# spannarboda -  Örebro län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Stora Skedvi', 'Region': 'Dalarnas län', 'Type': 'locality', 'Points': 0}
# stora skedvi -  Dalarnas län
# Type: <class 'list'>
# Size: 9
# {'Name': 'Storbron', 'Region': 'Värmlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# storbron -  Värmlands län
# Type: <class 'list'>
# Size: 0
# Type: <class 'list'>
# Size: 1
# {'Name': 'Storlien Handel', 'Region': 'Jämtlands län', 'Type': 'supermarket', 'Points': -2}
# storlien-storvallen -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Stormyra', 'Region': 'Stockholms län', 'Type': 'isolated_dwelling', 'Points': 1}
# stormyra -  Stockholms län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Vansö', 'Region': 'Södermanlands län', 'Type': 'village', 'Points': -2}
# strängnäs-vansö -  Södermanlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Edet', 'Region': 'Jämtlands län', 'Type': 'isolated_dwelling', 'Points': -1}
# strömsund-edet -  Jämtlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Stångsmåla', 'Region': 'Blekinge län', 'Type': 'isolated_dwelling', 'Points': 1}
# stångsmåla -  Blekinge län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Sunneränga', 'Region': 'Jönköpings län', 'Type': 'hamlet', 'Points': 0}
# sunneränga -  Jönköpings län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Svartberget', 'Region': 'Västerbottens län', 'Type': 'peak', 'Points': 0}
# svartberget -  Västerbottens län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Svedjelandet', 'Region': 'Stockholms län', 'Type': 'isolated_dwelling', 'Points': 1}
# svedjelandet -  Stockholms län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Eggarna', 'Region': 'Jämtlands län', 'Type': 'hamlet', 'Points': -2}
# sveg-eggarna -  Jämtlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Svenska Högarna', 'Region': 'Stockholms län', 'Type': 'nature_reserve', 'Points': 0}
# svenska högarna -  Stockholms län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Sågen', 'Region': 'Stockholms län', 'Type': 'isolated_dwelling', 'Points': 1}
# sågen -  Stockholms län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Såtenäs', 'Region': 'Västra Götalands län', 'Type': 'hamlet', 'Points': 0}
# såtenäs -  Västra Götalands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Söderby-Karlsäng', 'Region': 'Uppsala län', 'Type': 'hamlet', 'Points': 0}
# söderby-karlsäng -  Uppsala län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Söderköping', 'Region': 'Östergötlands län', 'Type': 'marina', 'Points': 0}
# söderköping -  Östergötlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Södersel', 'Region': 'Västernorrlands län', 'Type': 'hamlet', 'Points': 0}
# södersel -  Västernorrlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Södra Vi', 'Region': 'Kalmar län', 'Type': 'village', 'Points': 0}
# södra vi -  Kalmar län
# Type: <class 'list'>
# Size: 9
# {'Name': 'Sörbytorp', 'Region': 'Örebro län', 'Type': 'isolated_dwelling', 'Points': 1}
# sörbytorp -  Örebro län
# Type: <class 'list'>
# Size: 8
# {'Name': 'Talliden', 'Region': 'Kalmar län', 'Type': 'isolated_dwelling', 'Points': 1}
# talliden -  Kalmar län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Talljärv', 'Region': 'Norrbottens län', 'Type': 'hamlet', 'Points': 0}
# talljärv -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Degerhaga', 'Region': 'Kronobergs län', 'Type': 'hamlet', 'Points': -2}
# tingsryd-degerhaga -  Kronobergs län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Trelleborg', 'Region': 'Kronobergs län', 'Type': 'isolated_dwelling', 'Points': 1}
# trelleborg -  Kronobergs län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Trolleboda', 'Region': 'Kronobergs län', 'Type': 'hamlet', 'Points': 0}
# trolleboda -  Kronobergs län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Trängslet', 'Region': 'Dalarnas län', 'Type': 'dam', 'Points': 0}
# trängslet -  Dalarnas län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Tullus', 'Region': 'Jämtlands län', 'Type': 'hamlet', 'Points': 0}
# tullus -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Tvingelshed', 'Region': 'Blekinge län', 'Type': 'hamlet', 'Points': 0}
# tvingelshed -  Blekinge län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Tyllinge', 'Region': 'Kalmar län', 'Type': 'isolated_dwelling', 'Points': 1}
# tyllinge -  Kalmar län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Tänger', 'Region': 'Västra Götalands län', 'Type': 'isolated_dwelling', 'Points': 1}
# tänger -  Västra Götalands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Tärendö', 'Region': 'Norrbottens län', 'Type': 'village', 'Points': 0}
# tärendö -  Norrbottens län
# Type: <class 'list'>
# Size: 7
# {'Name': 'Tånga', 'Region': 'Uppsala län', 'Type': 'isolated_dwelling', 'Points': 1}
# tånga -  Uppsala län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Tåsan', 'Region': 'Västra Götalands län', 'Type': 'isolated_dwelling', 'Points': 1}
# tåsan -  Västra Götalands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Ulvsjön', 'Region': 'Värmlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# ulvsjön -  Värmlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Röbäcksdalen', 'Region': 'Västerbottens län', 'Type': 'administrative', 'Points': -2}
# umeå-röbäcksdalen -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Ungsberg', 'Region': 'Kalmar län', 'Type': 'hamlet', 'Points': 0}
# ungsberg -  Kalmar län
# Type: <class 'list'>
# Size: 7
# {'Name': 'Vadstena', 'Region': 'Östergötlands län', 'Type': 'information', 'Points': 0}
# vadstena -  Östergötlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Vallbo', 'Region': 'Södermanlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# vallbo -  Södermanlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Valsjöbyn', 'Region': 'Jämtlands län', 'Type': 'village', 'Points': 0}
# valsjöbyn -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Mogatan', 'Region': 'Norrbottens län', 'Type': 'residential', 'Points': -2}
# vidsel mo -  Norrbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Sunnansjönäs', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': -2}
# vindeln-sunnansjönäs -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Rödmossavägen', 'Region': 'Kalmar län', 'Type': 'primary', 'Points': -2}
# virserum-rödmossa -  Kalmar län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Vällnora', 'Region': 'Uppsala län', 'Type': 'village', 'Points': 0}
# vällnora -  Uppsala län
# Type: <class 'list'>
# Size: 9
# {'Name': 'Vännäs', 'Region': 'Västerbottens län', 'Type': 'station', 'Points': 0}
# vännäs -  Västerbottens län
# Type: <class 'list'>
# Size: 0
# Type: <class 'list'>
# Size: 1
# {'Name': 'Västvalla', 'Region': 'Örebro län', 'Type': 'farmyard', 'Points': 0}
# västvalla -  Örebro län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Ytterberg', 'Region': 'Jämtlands län', 'Type': 'village', 'Points': 0}
# ytterberg -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Ytterrissjö', 'Region': 'Västerbottens län', 'Type': 'hamlet', 'Points': 0}
# ytterrissjö -  Västerbottens län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Zinkgruvan', 'Region': 'Örebro län', 'Type': 'village', 'Points': 0}
# zinkgruvan -  Örebro län
# Type: <class 'list'>
# Size: 5
# {'Name': 'Älgarås', 'Region': 'Västernorrlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# älgarås -  Västernorrlands län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Åda', 'Region': 'Södermanlands län', 'Type': 'farm', 'Points': 0}
# åda -  Södermanlands län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Åkroken', 'Region': 'Östergötlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# åkroken -  Östergötlands län
# Type: <class 'list'>
# Size: 9
# {'Name': 'Åminne', 'Region': 'Kronobergs län', 'Type': 'isolated_dwelling', 'Points': 1}
# åminne -  Kronobergs län
# Type: <class 'list'>
# Size: 3
# {'Name': 'Parteboda', 'Region': 'Västernorrlands län', 'Type': 'hamlet', 'Points': -2}
# ånge-parteboda -  Västernorrlands län
# Type: <class 'list'>
# Size: 4
# {'Name': 'Åsnorrbodarna', 'Region': 'Gävleborgs län', 'Type': 'hamlet', 'Points': 0}
# åsnorrbodarna -  Gävleborgs län
# Type: <class 'list'>
# Size: 2
# {'Name': 'Ölands norra udde', 'Region': 'Kalmar län', 'Type': 'attraction', 'Points': 0}
# ölands norra udde -  Kalmar län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Ön', 'Region': 'Jämtlands län', 'Type': 'island', 'Points': 0}
# ön -  Jämtlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Öningaryd', 'Region': 'Kalmar län', 'Type': 'isolated_dwelling', 'Points': 1}
# öningaryd -  Kalmar län
# Type: <class 'list'>
# Size: 10
# {'Name': 'Östanvik', 'Region': 'Värmlands län', 'Type': 'isolated_dwelling', 'Points': 1}
# östanvik -  Värmlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Åsarna', 'Region': 'Värmlands län', 'Type': 'isolated_dwelling', 'Points': -1}
# östmark-åsarna -  Värmlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Östra Husby', 'Region': 'Östergötlands län', 'Type': 'village', 'Points': 0}
# östra husby -  Östergötlands län
# Type: <class 'list'>
# Size: 1
# {'Name': 'Övre Soppero', 'Region': 'Norrbottens län', 'Type': 'village', 'Points': 0}
# övre soppero -  Norrbottens län

# %%
name_region_dataset = dic_to_df(ne_ops_ort, ["Name", "County"])

# %%
name_region_dataset.to_excel("name_region.xlsx")

# %%
ne_ops_ort
# Out:
# {'Abisko': 'Norrbottens län',
#  'Abraur': 'Norrbottens län',
#  'Adak': 'Västerbottens län',
#  'Alingsås D': 'stad) Västergötland (Västra Götalands län',
#  'Almdalen': 'Jämtlands län',
#  'Ankarsrum D': 'Kalmar län',
#  'Ankarvattnet D': 'Jämtlands län',
#  'Arjeplog-Myrheden D': 'Norrbottens län',
#  'Asker D': 'Stockholms län',
#  'Askim D': 'Västra Götalands län',
#  'Aspa D': 'Jönköpings län',
#  'Aspeå': 'Västerbottens län',
#  'Austers D': 'Gotlands län',
#  'Avasjö-Borgafjäll D': 'Västerbottens län',
#  'Avesta': 'stad) i Dalarna (Dalarnas län',
#  'Backe D': 'Jämtlands län',
#  'Bakarebo D': 'Östergötlands län',
#  'Balsjö D': 'Västerbottens län',
#  'Baramossa': 'Hallands län',
#  'Bastansjö D': 'Västerbottens län',
#  'Bengtsfors': 'Västra Götalands län',
#  'Berg': 'Västernorrlands län',
#  'Bergsjö': 'Gävleborgs län',
#  'Bispgården': 'Jämtlands län',
#  'Bjursås': 'Dalarnas län',
#  'Bjärnum D': 'Skåne län',
#  'Björklinge D': 'Uppsala län',
#  'Björkudden': 'Stockholms län',
#  'Björkvik D': 'Södermanlands län',
#  'Blaiken D': 'Västerbottens län',
#  'Bollebygd': 'Västra Götalands län',
#  'Bollnäs D': 'stad) i Hälsingland (Gävleborgs län',
#  'Borgvattnet D': 'Jämtlands län',
#  'Borlänge D': 'Dalarnas län',
#  'Borås': 'Västra Götalands län',
#  'Bottnaryd': 'Jönköpings län',
#  'Bottnen': 'Jämtlands län',
#  'Bredbyn D': 'Västernorrlands län',
#  'Bromölla': 'Skåne län',
#  'Brovallen': 'Dalarnas län',
#  'Brände': 'Västerbottens län',
#  'Brännberg D': 'Västerbottens län',
#  'Brännforssund': 'Västerbottens län',
#  'Brösarp D': 'Skåne län',
#  'Bygdsiljum D': 'Västerbottens län',
#  'Bäckefors': 'Västra Götalands län',
#  'Bäverträsk': 'Västerbottens län',
#  'Börrum D': 'Östergötlands län',
#  'Charlottenberg': 'Värmlands län',
#  'Dala-Järna D': 'Dalarnas län',
#  'Dalarö D': 'Stockholms län',
#  'Dalstorp': 'Västra Götalands län',
#  'Degeberga D': 'Skåne län',
#  'Degerfors D': 'Örebro län',
#  'Delsbo': 'Gävleborgs län',
#  'Digernäset D': 'Not found',
#  'Djursätra': 'Västra Götalands län',
#  'Djurö D': 'Stockholms län',
#  'Dödre': 'Jämtlands län',
#  'Ed D': 'Västra Götalands län',
#  'Edevik': 'Not found',
#  'Eftra D': 'Hallands län',
#  'Emmaboda D': 'Kalmar län',
#  'Enköping': 'Uppsala län',
#  'Eringsboda D': 'Blekinge län',
#  'Eskilstuna': 'Södermanlands län',
#  'Esrange': 'Norrbottens län',
#  'Fagerhult D': 'Kalmar län',
#  'Falköping-Valtorp D': 'Västra Götalands län',
#  'Falsterbo': 'Skåne län',
#  'Falun-Lugnet': 'Dalarnas län',
#  'Finnbacka D': 'Dalarnas län',
#  'Finspång': 'Östergötlands län',
#  'Fjällsjönäs': 'Västerbottens län',
#  'Forse': 'Gotlands län',
#  'Fotskäl D': 'Västra Götalands län',
#  'Fredriksberg': 'Dalarnas län',
#  'Fridlevstad D': 'Blekinge län',
#  'Frostviken D': 'Jämtlands län',
#  'Frändesta': 'Västmanlands län',
#  'Fägre D': 'Västra Götalands län',
#  'Fågelberget D': 'Södermanlands län',
#  'Fågelsjö D': 'Västmanlands län',
#  'Gargnäs D': 'Västerbottens län',
#  'Gendalen': 'Västra Götalands län',
#  'Gesunda D': 'Dalarnas län',
#  'Gillastig': 'Skåne län',
#  'Glindran': 'Södermanlands län',
#  'Glommersträsk': 'Norrbottens län',
#  'Godegård D': 'Östergötlands län',
#  'Granhed D': 'Södermanlands län',
#  'Granhult': 'Östergötlands län',
#  'Granö D': 'Västerbottens län',
#  'Grebbeshult': 'Västra Götalands län',
#  'Grythyttan': 'Örebro län',
#  'Gräsås D': 'Västra Götalands län',
#  'Grönliden': 'Västerbottens län',
#  'Gullspång': 'Västra Götalands län',
#  'Gustavsfors': 'Södermanlands län',
#  'Gustorp D': 'Östergötlands län',
#  'Gästrike-Hammarby D': 'Gävleborgs län',
#  'Gävle-Åbyggeby': 'Gävleborgs län',
#  'Gåltjärn': 'Västernorrlands län',
#  'Halmstad': 'Hallands län',
#  'Hammarö': 'Värmlands län',
#  'Hammerdal D': 'Jämtlands län',
#  'Handsjön D': 'Jämtlands län',
#  'Haparanda D': 'Norrbottens län',
#  'Harads D': 'Norrbottens län',
#  'Hattsjöbäcken D': 'Västernorrlands län',
#  'Heden': 'Västra Götalands län',
#  'Hedesunda': 'Gävleborgs län',
#  'Hedeviken': 'Jämtlands län',
#  'Hejnum': 'Gotlands län',
#  'Hellerö': 'Kalmar län',
#  'Hemse': 'Gotlands län',
#  'Hennan D': 'Gävleborgs län',
#  'Henån': 'Västra Götalands län',
#  'Herrljunga D': 'Västra Götalands län',
#  'Hestra D': 'Jönköpings län',
#  'Hid D': 'Västra Götalands län',
#  'Hillersboda': 'Dalarnas län',
#  'Hillsand': 'Jämtlands län',
#  'Hinshult': 'Kalmar län',
#  'Hjo': 'Västra Götalands län',
#  'Hjortkvarn D': 'Örebro län',
#  'Hoburg D': 'Gotlands län',
#  'Hofors': 'Gävleborgs län',
#  'Holmbo D': 'Västmanlands län',
#  'Holmfors D': 'Norrbottens län',
#  'Holmön D': 'Västerbottens län',
#  'Horred': 'Västra Götalands län',
#  'Hov': 'Östergötlands län',
#  'Hudiksvall': 'Gävleborgs län',
#  'Hult D': 'Jönköpings län',
#  'Hyltan': 'Jönköpings län',
#  'Hyndevad': 'Södermanlands län',
#  'Häggberget D': 'Dalarnas län',
#  'Häggårda': 'Västra Götalands län',
#  'Hälleforsnäs D': 'Södermanlands län',
#  'Härjeåsjön': 'Jämtlands län',
#  'Härnebo': 'Gävleborgs län',
#  'Härnösand': 'Västernorrlands län',
#  'Härryda': 'Västra Götalands län',
#  'Härsnäs': 'Västra Götalands län',
#  'Hässleby D': 'Jönköpings län',
#  'Håvelund': 'Not found',
#  'Högboda': 'Värmlands län',
#  'Högemålen D': 'Jönköpings län',
#  'Höglekardalen': 'Jämtlands län',
#  'Högsbo': 'Jönköpings län',
#  'Höljes': 'Värmlands län',
#  'Idre D': 'Dalarnas län',
#  'Jarhois': 'Norrbottens län',
#  'Jukkasjärvi D': 'Norrbottens län',
#  'Jäckvik': 'Norrbottens län',
#  'Järpströmmen': 'Jämtlands län',
#  'Järvsö': 'Gävleborgs län',
#  'Jönköping': 'Jönköpings län',
#  'Jörn D': 'Västerbottens län',
#  'Kalix D': 'Norrbottens län',
#  'Kalmar D': 'Kronobergs län',
#  'Kalvträsk D': 'Västerbottens län',
#  'Kangos D': 'Norrbottens län',
#  'Karesuando': 'Norrbottens län',
#  'Karlshamn': 'Södermanlands län',
#  'Karlskoga': 'Örebro län',
#  'Karlstad-Skåre': 'Värmlands län',
#  'Karungi': 'Norrbottens län',
#  'Katterjåkk': 'Norrbottens län',
#  'Kaxås-Åflo D': 'Jämtlands län',
#  'Kilafors D': 'Gävleborgs län',
#  'Kilagården': 'Västra Götalands län',
#  'Kindsboda': 'Västra Götalands län',
#  'Kindsjön D': 'Värmlands län',
#  'Kiruna': 'stad) i Lappland (Norrbottens län',
#  'Kisa D': 'Västra Götalands län',
#  'Kittelfjäll D': 'Västerbottens län',
#  'Klippan': 'Skåne län',
#  'Klöverträsk D': 'Norrbottens län',
#  'Knopparp D': 'Jönköpings län',
#  'Knäred D': 'Hallands län',
#  'Koler D': 'Norrbottens län',
#  'Kolsva D': 'Västmanlands län',
#  'Kopparberg D': 'Örebro län',
#  'Korsberga': 'Jönköpings län',
#  'Kramfors': 'Västernorrlands län',
#  'Kristianstad': 'Skåne län',
#  'Kristinehamn': 'Värmlands län',
#  'Krokshult D': 'Kronobergs län',
#  'Kråkemåla': 'Kalmar län',
#  'Kungsberget D': 'Gävleborgs län',
#  'Kungsör': 'Södermanlands län',
#  'Kusmark D': 'Västerbottens län',
#  'Kvikkjokk-Årrenjarka': 'Norrbottens län',
#  'Kypasjärvi D': 'Norrbottens län',
#  'Kyrktåsjö D': 'Jämtlands län',
#  'Källebäcken': 'Jönköpings län',
#  'Källsjö': 'Hallands län',
#  'Kärna': 'Östergötlands län',
#  'Kätkesuando': 'Norrbottens län',
#  'Kävsjö D': 'Jönköpings län',
#  'Kållered D': 'Västra Götalands län',
#  'Kölsillre': 'Västernorrlands län',
#  'Laholm D': 'Hallands län',
#  'Lainio': 'Norrbottens län',
#  'Landskrona D': 'Skåne län',
#  'Landsort': 'Södermanlands län',
#  'Lanna': 'Örebro län',
#  'Lannavaara D': 'Norrbottens län',
#  'Latikberg D': 'Västerbottens län',
#  'Leksand': 'Dalarnas län',
#  'Lesjöfors D': 'Värmlands län',
#  'Lessebo': 'Kronobergs län',
#  'Letafors D': 'Värmlands län',
#  'Lidhult D': 'Kronobergs län',
#  'Lidköping': 'Västra Götalands län',
#  'Lillhamra D': 'Västmanlands län',
#  'Linhult D': 'Hallands län',
#  'Linköping': 'Östergötlands län',
#  'Malmslätt': 'Östergötlands län',
#  'Ljugarn D': 'Gotlands län',
#  'Ljungby D': 'Kronobergs län',
#  'Ljusdals-Valsjön': 'Gävleborgs län',
#  'Ljusnedal': 'Jämtlands län',
#  'Lobonäs D': 'Gävleborgs län',
#  'Los D': 'Gävleborgs län',
#  'Louisefred': 'Skåne län',
#  'Ludvika': 'Dalarnas län',
#  'Luleå-Bergnäset': 'Norrbottens län',
#  'Luleå Flygplats': 'Norrbottens län',
#  'Lund': 'Skåne län',
#  'Lundsjön': 'Jämtlands län',
#  'Lyckeby': 'Blekinge län',
#  'Lysekil D': 'Västra Götalands län',
#  'Långan D': 'Jämtlands län',
#  'Löten D': 'Jämtlands län',
#  'Löttorp D': 'Kalmar län',
#  'Lövberga D': 'Stockholms län',
#  'Lövestad': 'Skåne län',
#  'Lövånger': 'Västerbottens län',
#  'Malkälen D': 'Västerbottens län',
#  'Malmberget': 'Norrbottens län',
#  'Malmbäck D': 'Jönköpings län',
#  'Malungsfors': 'Dalarnas län',
#  'Malå': 'Västerbottens län',
#  'Marby D': 'Jämtlands län',
#  'Marbäck D': 'Västra Götalands län',
#  'Mariefred': 'stad) i Strängnäs kommun, Södermanland (Södermanlands län',
#  'Mariestad': 'Västra Götalands län',
#  'Markaryd': 'Kronobergs län',
#  'Markusvinsa': 'Not found',
#  'Mjölkbäcken': 'Västerbottens län',
#  'Moheda D': 'Kronobergs län',
#  'Mollsjönäs D': 'Västra Götalands län',
#  'Mosekälla': 'Västerbottens län',
#  'Moskosel': 'Norrbottens län',
#  'Motala': 'Östergötlands län',
#  'Multrå D': 'Västernorrlands län',
#  'Munka-Ljungby D': 'Skåne län',
#  'Murjek D': 'Norrbottens län',
#  'Myckelgensjö': 'Västernorrlands län',
#  'Myre': 'Västernorrlands län',
#  'Myskelåsen D': 'Jämtlands län',
#  'Mälgåsen D': 'Jämtlands län',
#  'Mästerby': 'Gotlands län',
#  'Mångsbodarna': 'Dalarnas län',
#  'Mönsterås D': 'Kalmar län',
#  'Mörbylånga': 'Kalmar län',
#  'Mörsil': 'Jämtlands län',
#  'Nianfors': 'Gävleborgs län',
#  'Nobynäs D': 'Jönköpings län',
#  'Nora-Östanö D': 'Västernorrlands län',
#  'Norberg': 'Västmanlands län',
#  'Nordanbäck D': 'Dalarnas län',
#  'Nordanås': 'Västernorrlands län',
#  'Norderön': 'Jämtlands län',
#  'Nornäs D': 'Västra Götalands län',
#  'Norra Möckleby D': 'Kalmar län',
#  'Norra Ströö': 'Not found',
#  'Norra Vi D': 'Östergötlands län',
#  'Norrby S': 'Örebro län',
#  'Norrköping-SMHI': 'Östergötlands län',
#  'Norrveda': 'Stockholms län',
#  'Norsborg 2': 'Uppsala län',
#  'Nyhammar': 'Dalarnas län',
#  'Nyhamnsläge': 'Skåne län',
#  'Nyköping': 'Södermanlands län',
#  'Nynäshamn': 'Stockholms län',
#  'Nämdö': 'Stockholms län',
#  'Näshulta': 'Södermanlands län',
#  'Näsåker': 'Västernorrlands län',
#  'Nävelsjö': 'Jönköpings län',
#  'Ockelbo': 'Gävleborgs län',
#  'Olastorp': 'Värmlands län',
#  'Olofström': 'Blekinge län',
#  'Omberg D': 'Kalmar län',
#  'Onsala D': 'Hallands län',
#  'Orrefors D': 'Kalmar län',
#  'Orsa D': 'Dalarnas län',
#  'Osby': 'Skåne län',
#  'Oskarshamn': 'Kalmar län',
#  'Oxelösund': 'Södermanlands län',
#  'Parakka': 'Norrbottens län',
#  'Parkajoki': 'Norrbottens län',
#  'Persberg': 'Värmlands län',
#  'Piteå': 'Norrbottens län',
#  'Pjätteryd': 'Kronobergs län',
#  'Prästkulla': 'Östergötlands län',
#  'Puottaure': 'Norrbottens län',
#  'Ramsjöholm': 'Jönköpings län',
#  'Reftele D': 'Jönköpings län',
#  'Remningstorp': 'Västra Götalands län',
#  'Resele': 'Västernorrlands län',
#  'Rickleå': 'Västerbottens län',
#  'Riddarhyttan': 'Västmanlands län',
#  'Rissna D': 'Jämtlands län',
#  'Ronneby-Bredåkra': 'Blekinge län',
#  'Rossö': 'Västernorrlands län',
#  'Rossön': 'Jämtlands län',
#  'Rusksele D': 'Västerbottens län',
#  'Räfsebo D': 'Jönköpings län',
#  'Rödupp': 'Norrbottens län',
#  'Rörastrand': 'Västra Götalands län',
#  'Rörvik D': 'Jönköpings län',
#  'Saarikoski D': 'Norrbottens län',
#  'Sadiliden': 'Västerbottens län',
#  'Sadjem D': 'Norrbottens län',
#  'Saittarova D': 'Norrbottens län',
#  'Sala': 'Västmanlands län',
#  'Sanda': 'Gotlands län',
#  'Sandhamn D': 'Stockholms län',
#  'Sandhem': 'Jönköpings län',
#  'Segerstad': 'Kalmar län',
#  'Sidsjö D': 'Västernorrlands län',
#  'Silvergruvan': 'Värmlands län',
#  'Simeå': 'Gävleborgs län',
#  'Sjöbo D': 'Skåne län',
#  'Sjötofta D': 'Västra Götalands län',
#  'Skara': 'Gävleborgs län',
#  'Skattungbyn D': 'Dalarnas län',
#  'Skedemosse D': 'Kalmar län',
#  'Skeppshult D': 'Jönköpings län',
#  'Skröven D': 'Norrbottens län',
#  'Sköldinge': 'Södermanlands län',
#  'Skövde': 'Västra Götalands län',
#  'Slättån': 'Västernorrlands län',
#  'Sollefteå': 'Västernorrlands län',
#  'Sorsele': 'Västerbottens län',
#  'Spannarboda D': 'Örebro län',
#  'Stehag': 'Skåne län',
#  'Stiby': 'Skåne län',
#  'Stockholm': 'Stockholms län',
#  'Stora Skedvi': 'Dalarnas län',
#  'Storbron': 'Värmlands län',
#  'Stordalen-Midlanda D': 'Not found',
#  'Storlien-Storvallen': 'Jämtlands län',
#  'Stormyra': 'Stockholms län',
#  'Strängnäs-Vansö': 'Södermanlands län',
#  'Strömsund-Edet D': 'Jämtlands län',
#  'Ställdalen': 'Örebro län',
#  'Stångsmåla D': 'Blekinge län',
#  'Stöllet D': 'Värmlands län',
#  'Sunneränga': 'Jönköpings län',
#  'Svaneholm D': 'Skåne län',
#  'Svanstein': 'Norrbottens län',
#  'Svappavaara': 'Norrbottens län',
#  'Svartberget D': 'Västerbottens län',
#  'Svedjelandet': 'Stockholms län',
#  'Sveg-Eggarna': 'Jämtlands län',
#  'Svenska Högarna': 'Stockholms län',
#  'Sya': 'Östergötlands län',
#  'Säffle': 'Värmlands län',
#  'Särna D': 'Dalarnas län',
#  'Sätila': 'Västra Götalands län',
#  'Sävsjö': 'Jönköpings län',
#  'Sågen D': 'Stockholms län',
#  'Såtenäs': 'Västra Götalands län',
#  'Söderala D': 'Gävleborgs län',
#  'Söderby-Karlsäng D': 'Uppsala län',
#  'Söderbärke D': 'Dalarnas län',
#  'Söderköping': 'Östergötlands län',
#  'Södersel D': 'Västernorrlands län',
#  'Södertälje': 'Stockholms län',
#  'Södra Vi D': 'Kalmar län',
#  'Sölje D': 'Värmlands län',
#  'Söne': 'Västra Götalands län',
#  'Sörbytorp': 'Örebro län',
#  'Talliden': 'Kalmar län',
#  'Talljärv D': 'Norrbottens län',
#  'Tavelsjö D': 'Västerbottens län',
#  'Tingsryd-Degerhaga': 'Kronobergs län',
#  'Tjällmo D': 'Östergötlands län',
#  'Torsåker D': 'Gävleborgs län',
#  'Traneberg': 'Västra Götalands län',
#  'Trelleborg': 'Kronobergs län',
#  'Trolleboda D': 'Kronobergs län',
#  'Tryserum D': 'Östergötlands län',
#  'Trängslet': 'Dalarnas län',
#  'Trökörna': 'Västra Götalands län',
#  'Tullus D': 'Jämtlands län',
#  'Tvingelshed': 'Blekinge län',
#  'Tyllinge': 'Kalmar län',
#  'Tänger D': 'Västra Götalands län',
#  'Tärendö D': 'Norrbottens län',
#  'Tånga': 'Uppsala län',
#  'Tåsan': 'Västra Götalands län',
#  'Töcksfors': 'Värmlands län',
#  'Uddevalla D': 'Västra Götalands län',
#  'Ullånger': 'Västernorrlands län',
#  'Ulricehamn': 'Västra Götalands län',
#  'Ulvsjön D': 'Värmlands län',
#  'Umeå-Röbäcksdalen': 'Västerbottens län',
#  'Ungsberg': 'Kalmar län',
#  'Uppsala': 'Uppsala län',
#  'Vadstena D': 'Östergötlands län',
#  'Vagnhärad D': 'Södermanlands län',
#  'Vallbo': 'Södermanlands län',
#  'Vallentuna': 'Stockholms län',
#  'Valsjöbyn': 'Jämtlands län',
#  'Varberg': 'Hallands län',
#  'Vassunda': 'Uppsala län',
#  'Vattholma D': 'Uppsala län',
#  'Veddige D': 'Hallands län',
#  'Vedum': 'Västra Götalands län',
#  'Vidsel': 'Norrbottens län',
#  'Vidsel Mo': 'Norrbottens län',
#  'Vindeln-Sunnansjönäs': 'Västerbottens län',
#  'Vingåker D': 'Södermanlands län',
#  'Virserum-Rödmossa': 'Kalmar län',
#  'Visby D': 'stad) i Gotlands kommun, västra Gotland (Gotlands län',
#  'Vittinge': 'Uppsala län',
#  'Vomb': 'Skåne län',
#  'Vrena': 'Södermanlands län',
#  'Vuollerim': 'Norrbottens län',
#  'Vällnora D': 'Uppsala län',
#  'Vänersborg': 'Västra Götalands län',
#  'Vänge': 'Gotlands län',
#  'Vännäs D': 'Västerbottens län',
#  'Värmlandsnäs-Ekenäs D': 'Not found',
#  'Väse D': 'Värmlands län',
#  'Västerhaninge': 'Stockholms län',
#  'Västermo': 'Södermanlands län',
#  'Västerås': 'Västmanlands län',
#  'Västland': 'Uppsala län',
#  'Västvalla': 'Örebro län',
#  'Våmhus D': 'Dalarnas län',
#  'Vånga D': 'Skåne län',
#  'Vårgårda D': 'Västra Götalands län',
#  'Ystad': 'Skåne län',
#  'Ytterberg D': 'Jämtlands län',
#  'Ytterhogdal': 'Jämtlands län',
#  'Ytterrissjö D': 'Västerbottens län',
#  'Ytterselö D': 'Södermanlands län',
#  'Zinkgruvan': 'Örebro län',
#  'Älgarås D': 'Västernorrlands län',
#  'Älghult': 'Kronobergs län',
#  'Älvkarleby D': 'Uppsala län',
#  'Åby': 'Kalmar län',
#  'Åda': 'Södermanlands län',
#  'Åhus': 'Skåne län',
#  'Åkroken D': 'Östergötlands län',
#  'Åminne D': 'Kronobergs län',
#  'Ånge-Parteboda D': 'Västernorrlands län',
#  'Ånimskog': 'Västra Götalands län',
#  'Årjäng': 'Värmlands län',
#  'Åsarna D': 'Jämtlands län',
#  'Åsele': 'Västerbottens län',
#  'Åsnorrbodarna': 'Gävleborgs län',
#  'Åtorp': 'Örebro län',
#  'Ödeshög D': 'Östergötlands län',
#  'Ölands norra udde': 'Kalmar län',
#  'Ön': 'Jämtlands län',
#  'Öningaryd': 'Kalmar län',
#  'Örebro D': 'Örebro län',
#  'Örkelljunga': 'Skåne län',
#  'Örnsköldsvik': 'Västernorrlands län',
#  'Östanvik': 'Värmlands län',
#  'Österfärnebo': 'Gävleborgs län',
#  'Östervåla D': 'Uppsala län',
#  'Östmark-Åsarna': 'Värmlands län',
#  'Östra Husby D': 'Östergötlands län',
#  'Övertorneå': 'Norrbottens län',
#  'Övre Soppero': 'Norrbottens län'}
